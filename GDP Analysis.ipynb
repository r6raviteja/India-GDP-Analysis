# %% [markdown]
# # Introduction
# ## Import python libraries

# %%
import pandas as pd
import sys
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [20,10]

# %% [markdown]
# # Part I-A

# %% [markdown]
# Import dataset

# %%
gdp_current_price = pd.read_csv("Gross Domestic Product (GDP) at Current Price.csv")
gdp_current_price.head(10)
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14           12.85
# 1       (% Growth over previous year)  2014-15           13.40
# 2       (% Growth over previous year)  2015-16           15.85
# 3       (% Growth over previous year)  2016-17           14.65
# 4  GSDP - CURRENT PRICES (` in Crore)  2011-12       379402.00
# 5  GSDP - CURRENT PRICES (` in Crore)  2012-13       411404.00
# 6  GSDP - CURRENT PRICES (` in Crore)  2013-14       464272.00
# 7  GSDP - CURRENT PRICES (` in Crore)  2014-15       526468.00
# 8  GSDP - CURRENT PRICES (` in Crore)  2015-16       609934.00
# 9  GSDP - CURRENT PRICES (` in Crore)  2016-17       699307.00
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0              16.38      13.31      12.30         16.44     -5.77      11.47
# 1              14.79      11.45      17.92         13.69     13.12      10.82
# 2              12.07      13.19      10.59         10.98     10.75      11.09
# 3                NaN        NaN        NaN         11.26       NaN        NaN
# 4           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 5           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 6           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# 7           16761.00  198098.00  373920.00     234982.00  40633.00  895027.00
# 8           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
# 9                NaN        NaN        NaN     290140.00       NaN        NaN
#
#      Haryana      ...        Telangana   Tripura  Uttar Pradesh  Uttarakhand  \
# 0      15.45      ...            12.63     18.14          14.73        13.64
# 1       9.18      ...            13.05     15.92          10.51         8.12
# 2      10.91      ...            12.61       NaN          10.58        13.65
# 3      12.82      ...            13.67       NaN            NaN          NaN
# 4  297539.00      ...        359433.00  19208.00      724049.00    115523.00
# 5  347032.00      ...        401493.00  21663.00      822903.00    131835.00
# 6  400662.00      ...        452186.00  25593.00      944146.00    149817.00
# 7  437462.00      ...        511178.00  29667.00     1043371.00    161985.00
# 8  485184.00      ...        575631.00       NaN     1153795.00    184091.00
# 9  547396.00      ...        654294.00       NaN            NaN          NaN
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh      Delhi  Puducherry  \
# 0           NaN                      16.68       14.71      13.43       15.87
# 1           NaN                      10.89       12.33      10.96       10.14
# 2           NaN                        NaN        8.84      12.09       10.15
# 3           NaN                        NaN         NaN      12.76       11.40
# 4           NaN                    3979.00    18768.00  343767.00    16818.00
# 5           NaN                    4421.00    21609.00  391238.00    18875.00
# 6           NaN                    5159.00    24787.00  443783.00    21870.00
# 7           NaN                    5721.00    27844.00  492424.00    24089.00
# 8           NaN                        NaN    30304.00  551963.00    26533.00
# 9           NaN                        NaN         NaN  622385.00    29557.00
#
#    All_India GDP
# 0          12.97
# 1          10.65
# 2           9.99
# 3          11.52
# 4     8736039.00
# 5     9946636.00
# 6    11236635.00
# 7    12433749.00
# 8    13675331.00
# 9    15251028.00
#
# [10 rows x 36 columns]

# %%
 pd.pivot_table(gdp_current_price,index=["Items Description","Duration"])
# Out:
#                                              All_India GDP  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14           12.97
#                                    2014-15           10.65
#                                    2015-16            9.99
#                                    2016-17           11.52
# GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
#                                    2012-13      9946636.00
#                                    2013-14     11236635.00
#                                    2014-15     12433749.00
#                                    2015-16     13675331.00
#                                    2016-17     15251028.00
#
#                                              Andaman & Nicobar Islands  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14                       16.68
#                                    2014-15                       10.89
#                                    2015-16                         NaN
#                                    2016-17                         NaN
# GSDP - CURRENT PRICES (` in Crore) 2011-12                     3979.00
#                                    2012-13                     4421.00
#                                    2013-14                     5159.00
#                                    2014-15                     5721.00
#                                    2015-16                         NaN
#                                    2016-17                         NaN
#
#                                              Andhra Pradesh  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14            12.85
#                                    2014-15            13.40
#                                    2015-16            15.85
#                                    2016-17            14.65
# GSDP - CURRENT PRICES (` in Crore) 2011-12        379402.00
#                                    2012-13        411404.00
#                                    2013-14        464272.00
#                                    2014-15        526468.00
#                                    2015-16        609934.00
#                                    2016-17        699307.00
#
#                                              Arunachal Pradesh      Assam  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14               16.38      13.31
#                                    2014-15               14.79      11.45
#                                    2015-16               12.07      13.19
#                                    2016-17                 NaN        NaN
# GSDP - CURRENT PRICES (` in Crore) 2011-12            11063.00  143175.00
#                                    2012-13            12547.00  156864.00
#                                    2013-14            14602.00  177745.00
#                                    2014-15            16761.00  198098.00
#                                    2015-16            18784.00  224234.00
#                                    2016-17                 NaN        NaN
#
#                                                  Bihar  Chandigarh  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14       12.30       14.71
#                                    2014-15       17.92       12.33
#                                    2015-16       10.59        8.84
#                                    2016-17         NaN         NaN
# GSDP - CURRENT PRICES (` in Crore) 2011-12   247144.00    18768.00
#                                    2012-13   282368.00    21609.00
#                                    2013-14   317101.00    24787.00
#                                    2014-15   373920.00    27844.00
#                                    2015-16   413503.00    30304.00
#                                    2016-17         NaN         NaN
#
#                                              Chhattisgarh      Delhi  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14          16.44      13.43
#                                    2014-15          13.69      10.96
#                                    2015-16          10.98      12.09
#                                    2016-17          11.26      12.76
# GSDP - CURRENT PRICES (` in Crore) 2011-12      158074.00  343767.00
#                                    2012-13      177511.00  391238.00
#                                    2013-14      206690.00  443783.00
#                                    2014-15      234982.00  492424.00
#                                    2015-16      260776.00  551963.00
#                                    2016-17      290140.00  622385.00
#
#                                                   Goa     ...          Odisha  \
# Items Description                  Duration               ...
# (% Growth over previous year)      2013-14      -5.77     ...           12.95
#                                    2014-15      13.12     ...           10.37
#                                    2015-16      10.75     ...            6.19
#                                    2016-17        NaN     ...           10.85
# GSDP - CURRENT PRICES (` in Crore) 2011-12   42367.00     ...       227872.00
#                                    2012-13   38120.00     ...       258275.00
#                                    2013-14   35921.00     ...       291709.00
#                                    2014-15   40633.00     ...       321971.00
#                                    2015-16   45002.00     ...       341887.00
#                                    2016-17        NaN     ...       378991.00
#
#                                              Puducherry     Punjab  Rajasthan  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14        15.87      12.42      11.27
#                                    2014-15        10.14       9.95      11.37
#                                    2015-16        10.15        NaN        NaN
#                                    2016-17        11.40        NaN        NaN
# GSDP - CURRENT PRICES (` in Crore) 2011-12     16818.00  266628.00  436465.00
#                                    2012-13     18875.00  297734.00  494004.00
#                                    2013-14     21870.00  334714.00  549701.00
#                                    2014-15     24089.00  368011.00  612194.00
#                                    2015-16     26533.00        NaN        NaN
#                                    2016-17     29557.00        NaN        NaN
#
#                                                Sikkim  Tamil Nadu  Telangana  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14      12.35       13.51      12.63
#                                    2014-15       9.72       12.51      13.05
#                                    2015-16       9.39       10.99      12.61
#                                    2016-17        NaN       10.40      13.67
# GSDP - CURRENT PRICES (` in Crore) 2011-12   11165.00   751485.00  359433.00
#                                    2012-13   12338.00   855481.00  401493.00
#                                    2013-14   13862.00   971090.00  452186.00
#                                    2014-15   15209.00  1092564.00  511178.00
#                                    2015-16   16637.00  1212668.00  575631.00
#                                    2016-17        NaN  1338766.00  654294.00
#
#                                               Tripura  Uttar Pradesh  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14      18.14          14.73
#                                    2014-15      15.92          10.51
#                                    2015-16        NaN          10.58
#                                    2016-17        NaN            NaN
# GSDP - CURRENT PRICES (` in Crore) 2011-12   19208.00      724049.00
#                                    2012-13   21663.00      822903.00
#                                    2013-14   25593.00      944146.00
#                                    2014-15   29667.00     1043371.00
#                                    2015-16        NaN     1153795.00
#                                    2016-17        NaN            NaN
#
#                                              Uttarakhand
# Items Description                  Duration
# (% Growth over previous year)      2013-14         13.64
#                                    2014-15          8.12
#                                    2015-16         13.65
#                                    2016-17           NaN
# GSDP - CURRENT PRICES (` in Crore) 2011-12     115523.00
#                                    2012-13     131835.00
#                                    2013-14     149817.00
#                                    2014-15     161985.00
#                                    2015-16     184091.00
#                                    2016-17           NaN
#
# [10 rows x 33 columns]

# %% [markdown]
# ### Remove the following rows for the year 2016-17 as we there are lot of NaN in the year (% Growth over previous year) and GSDP - CURRENT PRICES (` in Crore)

# %%
# Drop (% Growth over previous year) for the year '2016-17'
index_to_drop = gdp_current_price.index[((gdp_current_price['Items Description']=='(% Growth over previous year)') & (gdp_current_price['Duration']=='2016-17'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)

# Drop (GSDP - CURRENT PRICES (` in Crore)) for the year '2016-17'
index_to_drop =  gdp_current_price.index[((gdp_current_price['Items Description']=='GSDP - CURRENT PRICES (` in Crore)') & (gdp_current_price['Duration']=='2016-17'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)

gdp_current_price
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14           12.85
# 1       (% Growth over previous year)  2014-15           13.40
# 2       (% Growth over previous year)  2015-16           15.85
# 4  GSDP - CURRENT PRICES (` in Crore)  2011-12       379402.00
# 5  GSDP - CURRENT PRICES (` in Crore)  2012-13       411404.00
# 6  GSDP - CURRENT PRICES (` in Crore)  2013-14       464272.00
# 7  GSDP - CURRENT PRICES (` in Crore)  2014-15       526468.00
# 8  GSDP - CURRENT PRICES (` in Crore)  2015-16       609934.00
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0              16.38      13.31      12.30         16.44     -5.77      11.47
# 1              14.79      11.45      17.92         13.69     13.12      10.82
# 2              12.07      13.19      10.59         10.98     10.75      11.09
# 4           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 5           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 6           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# 7           16761.00  198098.00  373920.00     234982.00  40633.00  895027.00
# 8           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
#
#      Haryana      ...        Telangana   Tripura  Uttar Pradesh  Uttarakhand  \
# 0      15.45      ...            12.63     18.14          14.73        13.64
# 1       9.18      ...            13.05     15.92          10.51         8.12
# 2      10.91      ...            12.61       NaN          10.58        13.65
# 4  297539.00      ...        359433.00  19208.00      724049.00    115523.00
# 5  347032.00      ...        401493.00  21663.00      822903.00    131835.00
# 6  400662.00      ...        452186.00  25593.00      944146.00    149817.00
# 7  437462.00      ...        511178.00  29667.00     1043371.00    161985.00
# 8  485184.00      ...        575631.00       NaN     1153795.00    184091.00
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh      Delhi  Puducherry  \
# 0           NaN                      16.68       14.71      13.43       15.87
# 1           NaN                      10.89       12.33      10.96       10.14
# 2           NaN                        NaN        8.84      12.09       10.15
# 4           NaN                    3979.00    18768.00  343767.00    16818.00
# 5           NaN                    4421.00    21609.00  391238.00    18875.00
# 6           NaN                    5159.00    24787.00  443783.00    21870.00
# 7           NaN                    5721.00    27844.00  492424.00    24089.00
# 8           NaN                        NaN    30304.00  551963.00    26533.00
#
#    All_India GDP
# 0          12.97
# 1          10.65
# 2           9.99
# 4     8736039.00
# 5     9946636.00
# 6    11236635.00
# 7    12433749.00
# 8    13675331.00
#
# [8 rows x 36 columns]

# %%
# inspect the structure etc.
print(gdp_current_price.info())
print(gdp_current_price.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 8
# Data columns (total 36 columns):
# Items Description            8 non-null object
# Duration                     8 non-null object
# Andhra Pradesh               8 non-null float64
# Arunachal Pradesh            8 non-null float64
# Assam                        8 non-null float64
# Bihar                        8 non-null float64
# Chhattisgarh                 8 non-null float64
# Goa                          8 non-null float64
# Gujarat                      8 non-null float64
# Haryana                      8 non-null float64
# Himachal Pradesh             6 non-null float64
# Jammu & Kashmir              8 non-null float64
# Jharkhand                    8 non-null float64
# Karnataka                    8 non-null float64
# Kerala                       8 non-null float64
# Madhya Pradesh               8 non-null float64
# Maharashtra                  6 non-null float64
# Manipur                      6 non-null float64
# Meghalaya                    8 non-null float64
# Mizoram                      6 non-null float64
# Nagaland                     6 non-null float64
# Odisha                       8 non-null float64
# Punjab                       6 non-null float64
# Rajasthan                    6 non-null float64
# Sikkim                       8 non-null float64
# Tamil Nadu                   8 non-null float64
# Telangana                    8 non-null float64
# Tripura                      6 non-null float64
# Uttar Pradesh                8 non-null float64
# Uttarakhand                  8 non-null float64
# West Bengal1                 0 non-null float64
# Andaman & Nicobar Islands    6 non-null float64
# Chandigarh                   8 non-null float64
# Delhi                        8 non-null float64
# Puducherry                   8 non-null float64
# All_India GDP                8 non-null float64
# dtypes: float64(34), object(2)
# memory usage: 2.3+ KB
# None
# (8, 36)

# %% [markdown]
# ## Get the names of the states/union territories present in the list. Will calculate mean GDP for these states

# %%
# Get the names of columns which has names of states/union territories and remove ('Items Description','Duration') 
column_attributes = list(gdp_current_price.columns.values)
list_remove = ('Items Description','Duration')  # Do not calculate mean for the these 2 columns
states = [ val for val in column_attributes if val not in list_remove] 
print(states)
# Out:
# ['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands', 'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP']

# %% [markdown]
# ## Loop through the states to calculate the average gdp growth of each state over the period 2013-14, 2014-15, 2015-16. States are present as column.

# %%
state_mean = {}
for column in gdp_current_price:
    # ignore the ('Items Description','Duration')
    if column in states:
        # calculate the mean of the 
        mean=gdp_current_price[gdp_current_price['Items Description']=='(% Growth over previous year)'][column].mean()
        # create a dictionary to store all the mean value of all the states
        state_mean[column]=mean
        
# Append state mean dictionary to the column 'Items Description' under the column name 'Average growth rate'
state_mean['Items Description']='Average growth rate'
gdp_current_price = gdp_current_price.append(state_mean, ignore_index=True)

# %%
# 'Average growth rate' is added under the category 'Item Description'
gdp_current_price
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14       12.850000
# 1       (% Growth over previous year)  2014-15       13.400000
# 2       (% Growth over previous year)  2015-16       15.850000
# 3  GSDP - CURRENT PRICES (` in Crore)  2011-12   379402.000000
# 4  GSDP - CURRENT PRICES (` in Crore)  2012-13   411404.000000
# 5  GSDP - CURRENT PRICES (` in Crore)  2013-14   464272.000000
# 6  GSDP - CURRENT PRICES (` in Crore)  2014-15   526468.000000
# 7  GSDP - CURRENT PRICES (` in Crore)  2015-16   609934.000000
# 8                 Average growth rate      NaN       14.033333
#
#    Arunachal Pradesh      Assam          Bihar   Chhattisgarh           Goa  \
# 0          16.380000      13.31      12.300000      16.440000     -5.770000
# 1          14.790000      11.45      17.920000      13.690000     13.120000
# 2          12.070000      13.19      10.590000      10.980000     10.750000
# 3       11063.000000  143175.00  247144.000000  158074.000000  42367.000000
# 4       12547.000000  156864.00  282368.000000  177511.000000  38120.000000
# 5       14602.000000  177745.00  317101.000000  206690.000000  35921.000000
# 6       16761.000000  198098.00  373920.000000  234982.000000  40633.000000
# 7       18784.000000  224234.00  413503.000000  260776.000000  45002.000000
# 8          14.413333      12.65      13.603333      13.703333      6.033333
#
#          Gujarat        Haryana      ...            Telangana   Tripura  \
# 0      11.470000      15.450000      ...            12.630000     18.14
# 1      10.820000       9.180000      ...            13.050000     15.92
# 2      11.090000      10.910000      ...            12.610000       NaN
# 3  615606.000000  297539.000000      ...        359433.000000  19208.00
# 4  724495.000000  347032.000000      ...        401493.000000  21663.00
# 5  807623.000000  400662.000000      ...        452186.000000  25593.00
# 6  895027.000000  437462.000000      ...        511178.000000  29667.00
# 7  994316.000000  485184.000000      ...        575631.000000       NaN
# 8      11.126667      11.846667      ...            12.763333     17.03
#
#    Uttar Pradesh    Uttarakhand  West Bengal1  Andaman & Nicobar Islands  \
# 0          14.73      13.640000           NaN                     16.680
# 1          10.51       8.120000           NaN                     10.890
# 2          10.58      13.650000           NaN                        NaN
# 3      724049.00  115523.000000           NaN                   3979.000
# 4      822903.00  131835.000000           NaN                   4421.000
# 5      944146.00  149817.000000           NaN                   5159.000
# 6     1043371.00  161985.000000           NaN                   5721.000
# 7     1153795.00  184091.000000           NaN                        NaN
# 8          11.94      11.803333           NaN                     13.785
#
#    Chandigarh      Delhi    Puducherry  All_India GDP
# 0       14.71      13.43     15.870000   1.297000e+01
# 1       12.33      10.96     10.140000   1.065000e+01
# 2        8.84      12.09     10.150000   9.990000e+00
# 3    18768.00  343767.00  16818.000000   8.736039e+06
# 4    21609.00  391238.00  18875.000000   9.946636e+06
# 5    24787.00  443783.00  21870.000000   1.123664e+07
# 6    27844.00  492424.00  24089.000000   1.243375e+07
# 7    30304.00  551963.00  26533.000000   1.367533e+07
# 8       11.96      12.16     12.053333   1.120333e+01
#
# [9 rows x 36 columns]

# %%
# Drop (% Growth over previous year) for the year '2013-14'
index_to_drop = gdp_current_price.index[((gdp_current_price['Items Description']=='(% Growth over previous year)') & (gdp_current_price['Duration']=='2013-14'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)

# Drop (% Growth over previous year) for the year '2014-15'
index_to_drop = gdp_current_price.index[((gdp_current_price['Items Description']=='(% Growth over previous year)') & (gdp_current_price['Duration']=='2014-15'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)


# Drop (GSDP - CURRENT PRICES (` in Crore)) for the year '2011-12'
index_to_drop =  gdp_current_price.index[((gdp_current_price['Items Description']=='GSDP - CURRENT PRICES (` in Crore)') & (gdp_current_price['Duration']=='2011-12'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)

# Drop (GSDP - CURRENT PRICES (` in Crore)) for the year '2012-12'
index_to_drop =  gdp_current_price.index[((gdp_current_price['Items Description']=='GSDP - CURRENT PRICES (` in Crore)') & (gdp_current_price['Duration']=='2012-13'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)

# Drop (GSDP - CURRENT PRICES (` in Crore)) for the year '2013-14'
index_to_drop =  gdp_current_price.index[((gdp_current_price['Items Description']=='GSDP - CURRENT PRICES (` in Crore)') & (gdp_current_price['Duration']=='2013-14'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)

# Drop (GSDP - CURRENT PRICES (` in Crore)) for the year '2014-15'
index_to_drop =  gdp_current_price.index[((gdp_current_price['Items Description']=='GSDP - CURRENT PRICES (` in Crore)') & (gdp_current_price['Duration']=='2014-15'))]
gdp_current_price = gdp_current_price.drop(index_to_drop)

# Remove Duration 
gdp_current_price = gdp_current_price.drop('Duration', axis = 1)

# %% [markdown]
# ## Plot the average GDP growth for all the states. To plot, we take the transpose and choose the column for which we want to plot

# %%
# Take transpose
gdp = gdp_current_price.T
# We also make some changes to make the column header as states, otherwise, we will get column header as index
header=gdp.iloc[0]
gdp=gdp[1:]
gdp.columns=header

# %%
gdp.index
# Out:
# Index(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal1',
#        'Andaman & Nicobar Islands', 'Chandigarh', 'Delhi', 'Puducherry',
#        'All_India GDP'],
#       dtype='object')

# %%
gdp
# Out:
# Items Description         (% Growth over previous year)  \
# Andhra Pradesh                                    15.85
# Arunachal Pradesh                                 12.07
# Assam                                             13.19
# Bihar                                             10.59
# Chhattisgarh                                      10.98
# Goa                                               10.75
# Gujarat                                           11.09
# Haryana                                           10.91
# Himachal Pradesh                                    NaN
# Jammu & Kashmir                                   17.91
# Jharkhand                                         11.44
# Karnataka                                         11.42
# Kerala                                            11.85
# Madhya Pradesh                                    12.86
# Maharashtra                                         NaN
# Manipur                                             NaN
# Meghalaya                                          9.58
# Mizoram                                             NaN
# Nagaland                                            NaN
# Odisha                                             6.19
# Punjab                                              NaN
# Rajasthan                                           NaN
# Sikkim                                             9.39
# Tamil Nadu                                        10.99
# Telangana                                         12.61
# Tripura                                             NaN
# Uttar Pradesh                                     10.58
# Uttarakhand                                       13.65
# West Bengal1                                        NaN
# Andaman & Nicobar Islands                           NaN
# Chandigarh                                         8.84
# Delhi                                             12.09
# Puducherry                                        10.15
# All_India GDP                                      9.99
#
# Items Description         GSDP - CURRENT PRICES (` in Crore)  \
# Andhra Pradesh                                        609934
# Arunachal Pradesh                                      18784
# Assam                                                 224234
# Bihar                                                 413503
# Chhattisgarh                                          260776
# Goa                                                    45002
# Gujarat                                               994316
# Haryana                                               485184
# Himachal Pradesh                                         NaN
# Jammu & Kashmir                                       118387
# Jharkhand                                             241955
# Karnataka                                        1.02707e+06
# Kerala                                                588337
# Madhya Pradesh                                        543975
# Maharashtra                                              NaN
# Manipur                                                  NaN
# Meghalaya                                              26745
# Mizoram                                                  NaN
# Nagaland                                                 NaN
# Odisha                                                341887
# Punjab                                                   NaN
# Rajasthan                                                NaN
# Sikkim                                                 16637
# Tamil Nadu                                       1.21267e+06
# Telangana                                             575631
# Tripura                                                  NaN
# Uttar Pradesh                                     1.1538e+06
# Uttarakhand                                           184091
# West Bengal1                                             NaN
# Andaman & Nicobar Islands                                NaN
# Chandigarh                                             30304
# Delhi                                                 551963
# Puducherry                                             26533
# All_India GDP                                    1.36753e+07
#
# Items Description         Average growth rate
# Andhra Pradesh                        14.0333
# Arunachal Pradesh                     14.4133
# Assam                                   12.65
# Bihar                                 13.6033
# Chhattisgarh                          13.7033
# Goa                                   6.03333
# Gujarat                               11.1267
# Haryana                               11.8467
# Himachal Pradesh                        12.28
# Jammu & Kashmir                          10.9
# Jharkhand                                11.5
# Karnataka                               14.12
# Kerala                                12.5833
# Madhya Pradesh                        12.6267
# Maharashtra                             11.26
# Manipur                                 14.61
# Meghalaya                             6.95333
# Mizoram                                  17.7
# Nagaland                               16.415
# Odisha                                9.83667
# Punjab                                 11.185
# Rajasthan                               11.32
# Sikkim                                10.4867
# Tamil Nadu                            12.3367
# Telangana                             12.7633
# Tripura                                 17.03
# Uttar Pradesh                           11.94
# Uttarakhand                           11.8033
# West Bengal1                              NaN
# Andaman & Nicobar Islands              13.785
# Chandigarh                              11.96
# Delhi                                   12.16
# Puducherry                            12.0533
# All_India GDP                         11.2033

# %% [markdown]
# ## Average GDP growth rate

# %%
# Plot average GDP growth rate
gdp['Average growth rate'].sort_values().plot.bar()

# %% [markdown]
# - Rate of GDP Growth in North East states like Mizoram, Tripura and Nagaland is high.
# - States like Goa, Meghalaya, Odisha, Sikkim and J&K is struggling with with GDP growth.
# - All India GDP growth is not so relatively low.
# - GDP growth of Bihar, Chattisgarh, A&N, Andhra Pradesh, Karnataka and Arunachal Pradesh are relatively high.
# - For all other states, GDP growth is medium.

# %% [markdown]
# ## Total GDP of the states for the year 2015-16

# %%
(gdp['GSDP - CURRENT PRICES (` in Crore)']).drop("All_India GDP", axis=0).sort_values().plot.bar()

# %% [markdown]
# Top 5 states: Tamil Nadu, Uttar Pradesh, Karnataka, Gujarat and Andhra Pradesh
# Bottom 5 states: Sikkim, Arunachal Pradesh, Puducherry, Meghalaya and Goa (excluding Chandigarh)

# %% [markdown]
# - GDP of Tamil Nadu, Uttar Pradesh, Karnataka and Gujarat are high.
# - Whereas, GDP of Rajasthan, Andhra Pradesh, Kerela, Telangana and Madhya Pradesh are not that great inspite of that they are big states.
# - The GDP of Haryana, Bihar, Punjab and Odisha are also low.
# - The GDP of Chattisgarh, Jharkhand, Assam, Uttrakhand, J&K are extremely low as they are relatively big states in terms of land.
# - The GDP of other small states like Goa, Tripuara, Meghalaya etc are low as they occupy less area.
# - The is no data for West Bengal, so it cannot be compared

# %% [markdown]
# # Part I-B
# For this part of the exercise, we will be considering base year as 2014-15 as GSDP data for all the states, except WB are present for the above time period.

# %%
# States to consider for the analysis
states = ['Andhra_Pradesh', 'Arunachal_Pradesh', 'Assam', 'Bihar',
       'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal_Pradesh',
       'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya_Pradesh',
       'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
       'Punjab', 'Rajasthan', 'Sikkim', 'Tamil_Nadu', 'Telangana', 'Tripura',
       'Uttar_Pradesh', 'Uttarakhand', 'West_Bengal']

# %% [markdown]
# ### Reading the GDP of individual states. Taking 2014-15 as the base year since the data for all the states(except WB) is present for this year.

# %%
import os, fnmatch

# Defining an empty dataframe. Will add the data of individual state to this dataframe. 
# GSVA = Gross State Value Added
gsva = pd.DataFrame()
# List of files where GSDP files are present
path=("C:\\Users\\govindam.kumar\\Documents\\Jupyter notebook\\GDP Analysis\\GSVA\\")
listOfFiles = os.listdir(path)  


for filename in listOfFiles:  
    for statename in states:
        if statename in filename:
            filepath = path+filename
            
            # use the following encoding "ISO-8859-1" otherwise it may create problem reading data for some states
            data_ = pd.read_csv(filepath, encoding = "ISO-8859-1")
            # select only the following columns, Items and year
            data_= data_[['Item', '2014-15']]
            # Take the transpose of the data before adding it to the dataframe
            data_ = data_.T
            header=data_.iloc[0]
            data_=data_[1:]
            data_.columns=header
            # print(statename)
            
            # Add data to the dataframe with their respective name of state. 
            # Careful with state having length of 2. Using space bewteen the words of a state as standard as it appears
            # in this format in the dataframe of Part I-A. 
            if statename=='Uttar_Pradesh':
                data_['state'] = 'Uttar Pradesh'
            elif statename=='Madhya_Pradesh':
                data_['state'] = 'Madhya Pradesh'
            elif statename=='Andhra_Pradesh':
                data_['state'] = 'Andhra Pradesh'   
            elif statename=='Arunachal_Pradesh':
                data_['state'] = 'Arunachal Pradesh'   
            elif statename=='Tamil_Nadu':
                data_['state'] = 'Tamil Nadu'   
            else:      
                data_['state'] = statename

            frames = [data_,gsva]
            gsva = pd.concat(frames)
# Out:
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
gsva.set_index('state', inplace=True)
gsva
# Out:
#                   Agriculture, forestry and fishing Air transport  \
# state
# Uttar Pradesh                              25097754         36582
# Uttarakhand                             1.60142e+06          3889
# Tripura                                      799825           NaN
# Telangana                                   7591501        120691
# Tamil Nadu                                 13064238        180836
# Sikkim                                       137447             0
# Rajasthan                                  15044394         13469
# Punjab                                      9285716          4473
# Odisha                                      6422978         15354
# Nagaland                                     607897          4153
# Meghalaya                                    366521          1443
# Manipur                                      383140          6288
# Maharashtra                                16475655        174188
# Madhya Pradesh                             16235647         26746
# Kerala                                      5930617        125029
# Karnataka                                  11219422        171785
# Jharkhand                                   3211065          6716
# Haryana                                 8.01524e+06           NaN
# Gujarat                                   1.377e+07           NaN
# Goa                                          308507         46359
# Chhattisgarh                                3948847          9507
# Bihar                                       7951890         13599
# Assam                                       3855548         26223
# Arunachal Pradesh                            686117             0
# Andhra Pradesh                             14819416         14900
#
#                   Communication & services related to broadcasting  \
# state
# Uttar Pradesh                                              1914737
# Uttarakhand                                                 733778
# Tripura                                                      66676
# Telangana                                                   753992
# Tamil Nadu                                                 1903283
# Sikkim                                                       12064
# Rajasthan                                                  1150955
# Punjab                                                      660819
# Odisha                                                      513531
# Nagaland                                                     37794
# Meghalaya                                                    40547
# Manipur                                                      42017
# Maharashtra                                                2551115
# Madhya Pradesh                                              905381
# Kerala                                                      884767
# Karnataka                                                  1349520
# Jharkhand                                                   323214
# Haryana                                                     479658
# Gujarat                                                1.24252e+06
# Goa                                                          44028
# Chhattisgarh                                                294552
# Bihar                                                       919427
# Assam                                                       357619
# Arunachal Pradesh                                            19568
# Andhra Pradesh                                              928756
#
#                   Construction        Crops  \
# state
# Uttar Pradesh         11256450     16215212
# Uttarakhand        1.34273e+06       866146
# Tripura                 177899       397591
# Telangana              2854024      4162493
# Tamil Nadu            12216718      7297820
# Sikkim                   82058       114976
# Rajasthan              5353326      7673441
# Punjab                 2202962      5690972
# Odisha                 2402396      4382636
# Nagaland                156072       375825
# Meghalaya               150256       223330
# Manipur                 143182       226583
# Maharashtra            9450211     10435121
# Madhya Pradesh         4403151     13216013
# Kerala                 7314003      3070386
# Karnataka              6104799      8157179
# Jharkhand              1789834      2094466
# Haryana            3.70257e+06  4.63673e+06
# Gujarat            5.52602e+06  9.67109e+06
# Goa                     165819       140421
# Chhattisgarh           2669855      2613371
# Bihar                  3449763      4688237
# Assam                  1733568      2890544
# Arunachal Pradesh       147842       415520
# Andhra Pradesh         4664889      7893514
#
#                   Electricity, gas, water supply & other utility services  \
# state
# Uttar Pradesh                                                2030625
# Uttarakhand                                                   433880
# Tripura                                                        77870
# Telangana                                                     716266
# Tamil Nadu                                                   1710379
# Sikkim                                                        212499
# Rajasthan                                                    1122888
# Punjab                                                        911611
# Odisha                                                        833067
# Nagaland                                                       37944
# Meghalaya                                                      54473
# Manipur                                                        27490
# Maharashtra                                                  4334702
# Madhya Pradesh                                               1272905
# Kerala                                                        482470
# Karnataka                                                    1425762
# Jharkhand                                                     337489
# Haryana                                                  1.10192e+06
# Gujarat                                                  3.40998e+06
# Goa                                                           204110
# Chhattisgarh                                                 1198438
# Bihar                                                         345168
# Assam                                                         296587
# Arunachal Pradesh                                             113527
# Andhra Pradesh                                               1151729
#
#                   Financial services Fishing and aquaculture  \
# state
# Uttar Pradesh                3392275                  380730
# Uttarakhand                   385030                    4796
# Tripura                        86094                  168961
# Telangana                    3023729                  266968
# Tamil Nadu                   5598498                  680352
# Sikkim                         21079                     604
# Rajasthan                    1827413                   58036
# Punjab                       2057520                  107657
# Odisha                       1065147                  460636
# Nagaland                       60393                    8470
# Meghalaya                      64091                    9583
# Manipur                        30315                   35243
# Maharashtra                 16143324                  475141
# Madhya Pradesh               1988794                  121277
# Kerala                       2010306                  704319
# Karnataka                    4094169                  500390
# Jharkhand                     551441                  108947
# Haryana                  1.67149e+06                  110080
# Gujarat                  4.60664e+06                  638357
# Goa                           233618                  122201
# Chhattisgarh                  739057                  385483
# Bihar                        1178022                  653224
# Assam                         543651                  529539
# Arunachal Pradesh              25207                    8193
# Andhra Pradesh               1900863                 2270664
#
#                   Forestry and logging Gross State Domestic Product  \
# state
# Uttar Pradesh                  1404936                    104337115
# Uttarakhand                     339293                  1.61985e+07
# Tripura                         145096                  2.96666e+06
# Telangana                       210741                     51117765
# Tamil Nadu                      392705                    109256373
# Sikkim                            4529                      1520933
# Rajasthan                      1956660                     61219447
# Punjab                          848245                     36801089
# Odisha                          791463                     32197092
# Nagaland                         99802                      1841424
# Meghalaya                        61166                  2.44081e+06
# Manipur                          45831                  1.80428e+06
# Maharashtra                    1592564                    179212165
# Madhya Pradesh                  965588                     48198169
# Kerala                          499808                     52600230
# Karnataka                       693082                     92178806
# Jharkhand                       445149                     21710718
# Haryana                         352254                  4.37462e+07
# Gujarat                         761616                  8.95027e+07
# Goa                              15744                      4063307
# Chhattisgarh                    597785                     23498180
# Bihar                           550132                     37391988
# Assam                           261987                     19809800
# Arunachal Pradesh               224017                      1676119
# Andhra Pradesh                  346160                     52646842
#
#                         ...       Storage Subsidies on products  \
# state                   ...
# Uttar Pradesh           ...        171696               3287219
# Uttarakhand             ...           660                313139
# Tripura                 ...           254                 94002
# Telangana               ...         19805                836700
# Tamil Nadu              ...         39834               2766405
# Sikkim                  ...             0                 18400
# Rajasthan               ...         16584               2333442
# Punjab                  ...         76429                911800
# Odisha                  ...         22675               1209349
# Nagaland                ...            89                 37745
# Meghalaya               ...           416                 62112
# Manipur                 ...           NaN                 69137
# Maharashtra             ...        131237               4017300
# Madhya Pradesh          ...         29012               2102800
# Kerala                  ...          3290                822381
# Karnataka               ...         42787               1889206
# Jharkhand               ...           306                411619
# Haryana                 ...         14459           1.06787e+06
# Gujarat                 ...         57634           1.98155e+06
# Goa                     ...           357                 61854
# Chhattisgarh            ...         16675               1332092
# Bihar                   ...         10618               2006421
# Assam                   ...         10308                582406
# Arunachal Pradesh       ...             0                 30272
# Andhra Pradesh          ...         18700               1690800
#
#                   TOTAL GSVA at basic prices Taxes on Products     Tertiary  \
# state
# Uttar Pradesh                       97516938          10107396     45968959
# Uttarakhand                      1.50768e+07       1.43486e+06  5.58798e+06
# Tripura                          2.91132e+06            149345  1.48471e+06
# Telangana                           47528765           4425700     28471410
# Tamil Nadu                          99515453          12507325     53343788
# Sikkim                               1467133             72200       483103
# Rajasthan                           58158386           5394503     26015812
# Punjab                              33918789           3794100     16717805
# Odisha                              30255256           3151184     12256258
# Nagaland                             1821495             57674       992956
# Meghalaya                        2.28965e+06            213272  1.20066e+06
# Manipur                          1.78065e+06             92766  1.17733e+06
# Maharashtra                        157834665          25394800     88631076
# Madhya Pradesh                      46016269           4284700     18117360
# Kerala                              48233259           5189352     29673778
# Karnataka                           83041338          11026674     50490630
# Jharkhand                           19623166           2499171      8133341
# Haryana                          3.98284e+07       4.98567e+06  1.92266e+07
# Gujarat                          7.91311e+07       1.23532e+07  3.02204e+07
# Goa                                  3597882            527279      1738217
# Chhattisgarh                        22228481           2601791      7588778
# Bihar                               36184863           3213546     22179969
# Assam                               18666897           1725309      9307109
# Arunachal Pradesh                    1636292             70099       631844
# Andhra Pradesh                      48825542           5512100     22032942
#
#                   Trade & repair services Trade & repair services*  \
# state
# Uttar Pradesh                     8476139                      NaN
# Uttarakhand                   1.53407e+06                      NaN
# Tripura                            390423                      NaN
# Telangana                         5724128                      NaN
# Tamil Nadu                       11252588                      NaN
# Sikkim                              64624                      NaN
# Rajasthan                         6942748                      NaN
# Punjab                            4201252                      NaN
# Odisha                            2886789                      NaN
# Nagaland                           134174                      NaN
# Meghalaya                          357727                      NaN
# Manipur                            253637                      NaN
# Maharashtra                      14286902                      NaN
# Madhya Pradesh                    5053625                      NaN
# Kerala                                NaN                  7763847
# Karnataka                         7523720                      NaN
# Jharkhand                         1840196                      NaN
# Haryana                       4.81778e+06                      NaN
# Gujarat                       1.01787e+07                      NaN
# Goa                                343492                      NaN
# Chhattisgarh                      1414164                      NaN
# Bihar                             7081391                      NaN
# Assam                             2876251                      NaN
# Arunachal Pradesh                   56796                      NaN
# Andhra Pradesh                    3716000                      NaN
#
#                   Trade, repair, hotels and restaurants  \
# state
# Uttar Pradesh                                   9437243
# Uttarakhand                                 1.74311e+06
# Tripura                                          390423
# Telangana                                       6494607
# Tamil Nadu                                     12895842
# Sikkim                                            70568
# Rajasthan                                       7297290
# Punjab                                          4419919
# Odisha                                          3149555
# Nagaland                                         140781
# Meghalaya                                        383974
# Manipur                                          262950
# Maharashtra                                    15839100
# Madhya Pradesh                                  5357515
# Kerala                                          8557345
# Karnataka                                       8991658
# Jharkhand                                       1991359
# Haryana                                     4.98632e+06
# Gujarat                                     1.01787e+07
# Goa                                              380927
# Chhattisgarh                                    1535571
# Bihar                                           7448373
# Assam                                           2987155
# Arunachal Pradesh                                 60421
# Andhra Pradesh                                  4233400
#
#                   Transport, storage, communication & services related to broadcasting  \
# state
# Uttar Pradesh                                                7404509
# Uttarakhand                                              1.06669e+06
# Tripura                                                       155956
# Telangana                                                    3604741
# Tamil Nadu                                                   7188320
# Sikkim                                                         47347
# Rajasthan                                                    3814461
# Punjab                                                       1951809
# Odisha                                                       2034016
# Nagaland                                                       77521
# Meghalaya                                                     148189
# Manipur                                                       109726
# Maharashtra                                                  9697246
# Madhya Pradesh                                               2865802
# Kerala                                                       4020934
# Karnataka                                                    5097652
# Jharkhand                                                    1470022
# Haryana                                                  2.56062e+06
# Gujarat                                                  4.55591e+06
# Goa                                                           189656
# Chhattisgarh                                                  871770
# Bihar                                                        3147173
# Assam                                                        1194568
# Arunachal Pradesh                                              35203
# Andhra Pradesh                                               5076984
#
#                   Water transport
# state
# Uttar Pradesh                 681
# Uttarakhand                   NaN
# Tripura                       NaN
# Telangana                       0
# Tamil Nadu                  70414
# Sikkim                          0
# Rajasthan                       0
# Punjab                          0
# Odisha                      50349
# Nagaland                      600
# Meghalaya                     NaN
# Manipur                       NaN
# Maharashtra                223626
# Madhya Pradesh                  0
# Kerala                      26956
# Karnataka                   24152
# Jharkhand                       0
# Haryana                       NaN
# Gujarat                       NaN
# Goa                         17820
# Chhattisgarh                    0
# Bihar                        2228
# Assam                        4502
# Arunachal Pradesh               0
# Andhra Pradesh              94200
#
# [25 rows x 37 columns]

# %%
gsva.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Air transport',
#        'Communication & services related to broadcasting', 'Construction',
#        'Crops', 'Electricity, gas, water supply & other utility services',
#        'Financial services', 'Fishing and aquaculture', 'Forestry and logging',
#        'Gross State Domestic Product', 'Hotels & restaurants', 'Livestock',
#        'Manufacturing', 'Mining and quarrying', 'Other services',
#        'Per Capita GSDP (Rs.)', 'Population ('00)', 'Primary',
#        'Public administration', 'Railways',
#        'Real estate, ownership of dwelling & professional services',
#        'Road transport', 'Road transport*', 'Road transport**', 'Secondary',
#        'Services incidental to transport', 'Services incidental to transport*',
#        'Storage', 'Subsidies on products', 'TOTAL GSVA at basic prices',
#        'Taxes on Products', 'Tertiary', 'Trade & repair services',
#        'Trade & repair services*', 'Trade, repair, hotels and restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Water transport'],
#       dtype='object')

# %%
gsva.index
# Out:
# Index(['Uttar Pradesh', 'Uttarakhand', 'Tripura', 'Telangana', 'Tamil Nadu',
#        'Sikkim', 'Rajasthan', 'Punjab', 'Odisha', 'Nagaland', 'Meghalaya',
#        'Manipur', 'Maharashtra', 'Madhya Pradesh', 'Kerala', 'Karnataka',
#        'Jharkhand', 'Haryana', 'Gujarat', 'Goa', 'Chhattisgarh', 'Bihar',
#        'Assam', 'Arunachal Pradesh', 'Andhra Pradesh'],
#       dtype='object', name='state')

# %% [markdown]
# ### Plotting the per capita GSDP

# %%
per_capita = gsva['Per Capita GSDP (Rs.)'].sort_values()
per_capita.plot.bar()
per_capita
# Out:
# state
# Bihar                 33954
# Uttar Pradesh         49450
# Manipur               58442
# Assam                 60621
# Jharkhand             62091
# Madhya Pradesh        62989
# Odisha                73979
# Meghalaya             76228
# Tripura               77358
# Rajasthan             84837
# Chhattisgarh          86860
# Nagaland              89607
# Andhra Pradesh       104977
# Arunachal Pradesh    112718
# Punjab               126606
# Telangana            139035
# Gujarat              141263
# Karnataka            145141
# Tamil Nadu           146503
# Maharashtra          152853
# Uttarakhand          153076
# Kerala               154778
# Haryana              164077
# Sikkim               240274
# Goa                  271793
# Name: Per Capita GSDP (Rs.), dtype: object

# %% [markdown]
# ### Identify the top-5 and the bottom-5 states based on GDP per capita.
# Top-5 states: Goa, Sikkim, Haryana, Kerala and Uttarakhand
#
# ### Find the ratio of highest per capita GDP to the lowest per capita GDP.

# %%
per_capita['Goa']/per_capita['Bihar']
# Out:
# 8.004741709371503

# %% [markdown]
# ### Other analysis
# - Goa, which has the lowest GDP growth rate has the second highest per capita GSDP.
# - Big states like Uttrakhand, Tamil Nadu, Karnataka, Gujarat, Telangana and Punjab has decent per capita income and decent GDP.
# - Big states like Andhra Pradesh, Chattisgarh, Rajasthan and Odisha has low per capita GSDP. Their GDP is also not that high.
# - Uttar Pradesh, which has one of the highest GSPD has the second lowest per capita GSDP.
# - States like Bihar, Assam and Jharkhand have low GSDP as well as low per capita GSDP.

# %%
per_capita.mean()
# Out:
# 114780.4

# %% [markdown]
# ## Finding the depedency of GDP on primary, secondary and tertiary.

# %%
# creating a time slot for various time period of day
def gdp_percentage(gsdp, total_gsdp):
    return gsdp/total_gsdp
    
gsva['primary_gdp_percent'] = gsva[['Primary','Gross State Domestic Product']].apply(lambda x: gdp_percentage(*x), axis=1)
gsva['secondary_gdp_percent'] = gsva[['Secondary','Gross State Domestic Product']].apply(lambda x: gdp_percentage(*x), axis=1)
gsva['tertiary_gdp_percent'] = gsva[['Tertiary','Gross State Domestic Product']].apply(lambda x: gdp_percentage(*x), axis=1)

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing Air transport  \
# state
# Uttar Pradesh                              25097754         36582
# Uttarakhand                             1.60142e+06          3889
# Tripura                                      799825           NaN
# Telangana                                   7591501        120691
# Tamil Nadu                                 13064238        180836
# Sikkim                                       137447             0
# Rajasthan                                  15044394         13469
# Punjab                                      9285716          4473
# Odisha                                      6422978         15354
# Nagaland                                     607897          4153
# Meghalaya                                    366521          1443
# Manipur                                      383140          6288
# Maharashtra                                16475655        174188
# Madhya Pradesh                             16235647         26746
# Kerala                                      5930617        125029
# Karnataka                                  11219422        171785
# Jharkhand                                   3211065          6716
# Haryana                                 8.01524e+06           NaN
# Gujarat                                   1.377e+07           NaN
# Goa                                          308507         46359
# Chhattisgarh                                3948847          9507
# Bihar                                       7951890         13599
# Assam                                       3855548         26223
# Arunachal Pradesh                            686117             0
# Andhra Pradesh                             14819416         14900
#
#                   Communication & services related to broadcasting  \
# state
# Uttar Pradesh                                              1914737
# Uttarakhand                                                 733778
# Tripura                                                      66676
# Telangana                                                   753992
# Tamil Nadu                                                 1903283
# Sikkim                                                       12064
# Rajasthan                                                  1150955
# Punjab                                                      660819
# Odisha                                                      513531
# Nagaland                                                     37794
# Meghalaya                                                    40547
# Manipur                                                      42017
# Maharashtra                                                2551115
# Madhya Pradesh                                              905381
# Kerala                                                      884767
# Karnataka                                                  1349520
# Jharkhand                                                   323214
# Haryana                                                     479658
# Gujarat                                                1.24252e+06
# Goa                                                          44028
# Chhattisgarh                                                294552
# Bihar                                                       919427
# Assam                                                       357619
# Arunachal Pradesh                                            19568
# Andhra Pradesh                                              928756
#
#                   Construction        Crops  \
# state
# Uttar Pradesh         11256450     16215212
# Uttarakhand        1.34273e+06       866146
# Tripura                 177899       397591
# Telangana              2854024      4162493
# Tamil Nadu            12216718      7297820
# Sikkim                   82058       114976
# Rajasthan              5353326      7673441
# Punjab                 2202962      5690972
# Odisha                 2402396      4382636
# Nagaland                156072       375825
# Meghalaya               150256       223330
# Manipur                 143182       226583
# Maharashtra            9450211     10435121
# Madhya Pradesh         4403151     13216013
# Kerala                 7314003      3070386
# Karnataka              6104799      8157179
# Jharkhand              1789834      2094466
# Haryana            3.70257e+06  4.63673e+06
# Gujarat            5.52602e+06  9.67109e+06
# Goa                     165819       140421
# Chhattisgarh           2669855      2613371
# Bihar                  3449763      4688237
# Assam                  1733568      2890544
# Arunachal Pradesh       147842       415520
# Andhra Pradesh         4664889      7893514
#
#                   Electricity, gas, water supply & other utility services  \
# state
# Uttar Pradesh                                                2030625
# Uttarakhand                                                   433880
# Tripura                                                        77870
# Telangana                                                     716266
# Tamil Nadu                                                   1710379
# Sikkim                                                        212499
# Rajasthan                                                    1122888
# Punjab                                                        911611
# Odisha                                                        833067
# Nagaland                                                       37944
# Meghalaya                                                      54473
# Manipur                                                        27490
# Maharashtra                                                  4334702
# Madhya Pradesh                                               1272905
# Kerala                                                        482470
# Karnataka                                                    1425762
# Jharkhand                                                     337489
# Haryana                                                  1.10192e+06
# Gujarat                                                  3.40998e+06
# Goa                                                           204110
# Chhattisgarh                                                 1198438
# Bihar                                                         345168
# Assam                                                         296587
# Arunachal Pradesh                                             113527
# Andhra Pradesh                                               1151729
#
#                   Financial services Fishing and aquaculture  \
# state
# Uttar Pradesh                3392275                  380730
# Uttarakhand                   385030                    4796
# Tripura                        86094                  168961
# Telangana                    3023729                  266968
# Tamil Nadu                   5598498                  680352
# Sikkim                         21079                     604
# Rajasthan                    1827413                   58036
# Punjab                       2057520                  107657
# Odisha                       1065147                  460636
# Nagaland                       60393                    8470
# Meghalaya                      64091                    9583
# Manipur                        30315                   35243
# Maharashtra                 16143324                  475141
# Madhya Pradesh               1988794                  121277
# Kerala                       2010306                  704319
# Karnataka                    4094169                  500390
# Jharkhand                     551441                  108947
# Haryana                  1.67149e+06                  110080
# Gujarat                  4.60664e+06                  638357
# Goa                           233618                  122201
# Chhattisgarh                  739057                  385483
# Bihar                        1178022                  653224
# Assam                         543651                  529539
# Arunachal Pradesh              25207                    8193
# Andhra Pradesh               1900863                 2270664
#
#                   Forestry and logging Gross State Domestic Product  \
# state
# Uttar Pradesh                  1404936                    104337115
# Uttarakhand                     339293                  1.61985e+07
# Tripura                         145096                  2.96666e+06
# Telangana                       210741                     51117765
# Tamil Nadu                      392705                    109256373
# Sikkim                            4529                      1520933
# Rajasthan                      1956660                     61219447
# Punjab                          848245                     36801089
# Odisha                          791463                     32197092
# Nagaland                         99802                      1841424
# Meghalaya                        61166                  2.44081e+06
# Manipur                          45831                  1.80428e+06
# Maharashtra                    1592564                    179212165
# Madhya Pradesh                  965588                     48198169
# Kerala                          499808                     52600230
# Karnataka                       693082                     92178806
# Jharkhand                       445149                     21710718
# Haryana                         352254                  4.37462e+07
# Gujarat                         761616                  8.95027e+07
# Goa                              15744                      4063307
# Chhattisgarh                    597785                     23498180
# Bihar                           550132                     37391988
# Assam                           261987                     19809800
# Arunachal Pradesh               224017                      1676119
# Andhra Pradesh                  346160                     52646842
#
#                           ...          Taxes on Products     Tertiary  \
# state                     ...
# Uttar Pradesh             ...                   10107396     45968959
# Uttarakhand               ...                1.43486e+06  5.58798e+06
# Tripura                   ...                     149345  1.48471e+06
# Telangana                 ...                    4425700     28471410
# Tamil Nadu                ...                   12507325     53343788
# Sikkim                    ...                      72200       483103
# Rajasthan                 ...                    5394503     26015812
# Punjab                    ...                    3794100     16717805
# Odisha                    ...                    3151184     12256258
# Nagaland                  ...                      57674       992956
# Meghalaya                 ...                     213272  1.20066e+06
# Manipur                   ...                      92766  1.17733e+06
# Maharashtra               ...                   25394800     88631076
# Madhya Pradesh            ...                    4284700     18117360
# Kerala                    ...                    5189352     29673778
# Karnataka                 ...                   11026674     50490630
# Jharkhand                 ...                    2499171      8133341
# Haryana                   ...                4.98567e+06  1.92266e+07
# Gujarat                   ...                1.23532e+07  3.02204e+07
# Goa                       ...                     527279      1738217
# Chhattisgarh              ...                    2601791      7588778
# Bihar                     ...                    3213546     22179969
# Assam                     ...                    1725309      9307109
# Arunachal Pradesh         ...                      70099       631844
# Andhra Pradesh            ...                    5512100     22032942
#
#                   Trade & repair services Trade & repair services*  \
# state
# Uttar Pradesh                     8476139                      NaN
# Uttarakhand                   1.53407e+06                      NaN
# Tripura                            390423                      NaN
# Telangana                         5724128                      NaN
# Tamil Nadu                       11252588                      NaN
# Sikkim                              64624                      NaN
# Rajasthan                         6942748                      NaN
# Punjab                            4201252                      NaN
# Odisha                            2886789                      NaN
# Nagaland                           134174                      NaN
# Meghalaya                          357727                      NaN
# Manipur                            253637                      NaN
# Maharashtra                      14286902                      NaN
# Madhya Pradesh                    5053625                      NaN
# Kerala                                NaN                  7763847
# Karnataka                         7523720                      NaN
# Jharkhand                         1840196                      NaN
# Haryana                       4.81778e+06                      NaN
# Gujarat                       1.01787e+07                      NaN
# Goa                                343492                      NaN
# Chhattisgarh                      1414164                      NaN
# Bihar                             7081391                      NaN
# Assam                             2876251                      NaN
# Arunachal Pradesh                   56796                      NaN
# Andhra Pradesh                    3716000                      NaN
#
#                   Trade, repair, hotels and restaurants  \
# state
# Uttar Pradesh                                   9437243
# Uttarakhand                                 1.74311e+06
# Tripura                                          390423
# Telangana                                       6494607
# Tamil Nadu                                     12895842
# Sikkim                                            70568
# Rajasthan                                       7297290
# Punjab                                          4419919
# Odisha                                          3149555
# Nagaland                                         140781
# Meghalaya                                        383974
# Manipur                                          262950
# Maharashtra                                    15839100
# Madhya Pradesh                                  5357515
# Kerala                                          8557345
# Karnataka                                       8991658
# Jharkhand                                       1991359
# Haryana                                     4.98632e+06
# Gujarat                                     1.01787e+07
# Goa                                              380927
# Chhattisgarh                                    1535571
# Bihar                                           7448373
# Assam                                           2987155
# Arunachal Pradesh                                 60421
# Andhra Pradesh                                  4233400
#
#                   Transport, storage, communication & services related to broadcasting  \
# state
# Uttar Pradesh                                                7404509
# Uttarakhand                                              1.06669e+06
# Tripura                                                       155956
# Telangana                                                    3604741
# Tamil Nadu                                                   7188320
# Sikkim                                                         47347
# Rajasthan                                                    3814461
# Punjab                                                       1951809
# Odisha                                                       2034016
# Nagaland                                                       77521
# Meghalaya                                                     148189
# Manipur                                                       109726
# Maharashtra                                                  9697246
# Madhya Pradesh                                               2865802
# Kerala                                                       4020934
# Karnataka                                                    5097652
# Jharkhand                                                    1470022
# Haryana                                                  2.56062e+06
# Gujarat                                                  4.55591e+06
# Goa                                                           189656
# Chhattisgarh                                                  871770
# Bihar                                                        3147173
# Assam                                                        1194568
# Arunachal Pradesh                                              35203
# Andhra Pradesh                                               5076984
#
#                   Water transport primary_gdp_percent secondary_gdp_percent  \
# state
# Uttar Pradesh                 681            0.249185              0.244867
# Uttarakhand                   NaN            0.113959              0.471825
# Tripura                       NaN            0.317601              0.163279
# Telangana                       0            0.178673              0.194140
# Tamil Nadu                  70414            0.122005              0.300595
# Sikkim                          0            0.091244              0.555746
# Rajasthan                       0            0.312217              0.212821
# Punjab                          0            0.252603              0.214801
# Odisha                      50349            0.279817              0.279208
# Nagaland                      600            0.334620              0.115324
# Meghalaya                     NaN            0.184795              0.261365
# Manipur                       NaN            0.212351              0.122028
# Maharashtra                223626            0.121411              0.264743
# Madhya Pradesh                  0            0.370429              0.208408
# Kerala                      26956            0.123373              0.229467
# Karnataka                   24152            0.130901              0.222225
# Jharkhand                       0            0.241740              0.287483
# Haryana                       NaN            0.183797              0.287143
# Gujarat                       NaN            0.177505              0.368967
# Goa                         17820            0.076816              0.380856
# Chhattisgarh                    0            0.272396              0.350618
# Bihar                        2228            0.214484              0.160058
# Assam                        4502            0.268892              0.203591
# Arunachal Pradesh               0            0.427749              0.171521
# Andhra Pradesh              94200            0.309681              0.199231
#
#                   tertiary_gdp_percent
# state
# Uttar Pradesh                 0.440581
# Uttarakhand                   0.344968
# Tripura                       0.500464
# Telangana                     0.556977
# Tamil Nadu                    0.488244
# Sikkim                        0.317636
# Rajasthan                     0.424960
# Punjab                        0.454275
# Odisha                        0.380664
# Nagaland                      0.539233
# Meghalaya                     0.491909
# Manipur                       0.652524
# Maharashtra                   0.494559
# Madhya Pradesh                0.375893
# Kerala                        0.564138
# Karnataka                     0.547747
# Jharkhand                     0.374623
# Haryana                       0.439503
# Gujarat                       0.337648
# Goa                           0.427784
# Chhattisgarh                  0.322952
# Bihar                         0.593174
# Assam                         0.469823
# Arunachal Pradesh             0.376968
# Andhra Pradesh                0.418505
#
# [25 rows x 40 columns]

# %% [markdown]
# ### Plotting the percentage contribution of primary, secondary and tertiary sectors as a percentage of total GSDP for all the states.

# %%
gsva = gsva.sort_values('Per Capita GSDP (Rs.)')
gsva[['primary_gdp_percent', 'secondary_gdp_percent', 'tertiary_gdp_percent']].plot(kind='bar', stacked=True)
gsva[["Population ('00)"]].plot(kind='bar')

# %% [markdown]
# ### Some Observations
# - For states which has low per capita income, has significant dependence on primary source whereas states which have high per capita income relies more on secondary and tertiary.
# - UP has high GDP but due to its population, has low per capita income
# - Madhya Pradesh also has low per capita income, but mainly due to over dependence on primary source.
# - Arunachal Pradesh has decent per capita income inspite of heavily dependence on primary source as its population is significantly low.
# - States like Assam and Jharkhand go together with similar per capita income, GDP and dependence on primary, secondary and tertiary source.

# %% [markdown]
# ### Dividing the states as per Quantile

# %%
per_capita.quantile([0.20, 0.5, 0.85, 1])
# Out:
# 0.20    62809.4
# 0.50     104977
# 0.85     153757
# 1.00     271793
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
per_capita.sort_values(ascending=False)
# Out:
# state
# Goa                  271793
# Sikkim               240274
# Haryana              164077
# Kerala               154778
# Uttarakhand          153076
# Maharashtra          152853
# Tamil Nadu           146503
# Karnataka            145141
# Gujarat              141263
# Telangana            139035
# Punjab               126606
# Arunachal Pradesh    112718
# Andhra Pradesh       104977
# Nagaland              89607
# Chhattisgarh          86860
# Rajasthan             84837
# Tripura               77358
# Meghalaya             76228
# Odisha                73979
# Madhya Pradesh        62989
# Jharkhand             62091
# Assam                 60621
# Manipur               58442
# Uttar Pradesh         49450
# Bihar                 33954
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
category_1 = ['Goa', 'Sikkim', 'Kerala', 'Haryana']
category_2 = ['Arunachal Pradesh', 'Punjab','Telangana', 'Gujarat', 'Karnataka', 'Tamil Nadu',
       'Maharashtra', 'Uttarakhand']
#category_3 = ['Andhra Pradesh',
category_3 = [ 'Madhya Pradesh', 'Odisha', 'Meghalaya', 'Tripura', 'Rajasthan',
       'Chhattisgarh', 'Nagaland', 'Andhra Pradesh']
category_4 = ['Bihar', 'Uttar Pradesh', 'Manipur', 'Assam', 'Jharkhand' ]

# Excluding categories like GSDP,GSVP, primary, secondary and tertiary as represent aggregate and here we are trying to
# find the dependence on each of the sub-categories
categories_columns = ['Agriculture, forestry and fishing', 'Mining and quarrying', 'Manufacturing',
                      'Electricity, gas, water supply & other utility services', 'Construction',
                      'Trade, repair, hotels and restaurants',
                      'Transport, storage, communication & services related to broadcasting', 
                      'Financial services', 'Real estate, ownership of dwelling & professional services',
                      'Public administration', 'Other services', 'Taxes on Products', 'Subsidies on products']

# %% [markdown]
# ## Category_1 States

# %%
agg = gsva.loc[category_1][categories_columns].sum()
agg_gsdp = gsva.loc[category_1]['Gross State Domestic Product'].sum()
percentage_contribution = (round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:6]).sum()
print(percentage_contribution)
# plot
(round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:6]).plot.bar()
# Out:
# 77.0

# %% [markdown]
# ## Category_2 States

# %%
agg = gsva.loc[category_2][categories_columns].sum()
agg_gsdp = gsva.loc[category_2]['Gross State Domestic Product'].sum()
percentage_contribution = (round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:6]).sum()
print(percentage_contribution)
# plot
(round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:6]).plot.bar()
# Out:
# 78.0

# %% [markdown]
# ## Category_3 States

# %%
agg = gsva.loc[category_3][categories_columns].sum()
agg_gsdp = gsva.loc[category_3]['Gross State Domestic Product'].sum()
percentage_contribution = (round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:7]).sum()
print(percentage_contribution)
# plot
(round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:7]).plot.bar()
# Out:
# 81.0

# %% [markdown]
# ## Category_4 States

# %%
agg = gsva.loc[category_4][categories_columns].sum()
agg_gsdp = gsva.loc[category_4]['Gross State Domestic Product'].sum()
percentage_contribution = (round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:6]).sum()
print(percentage_contribution)
# plot
(round(100*(agg/(agg_gsdp))).sort_values(ascending=False)[0:6]).plot.bar()
# Out:
# 77.0

# %% [markdown]
# ##  Recommendations
#
# Category I: 'Goa', 'Sikkim', 'Kerala', 'Haryana'.
# There are only 4 states in this category, all of which are small (area wise) and have good industial base, agricultural, trade and real state. For North-Eastern states, Sikkim can be a role model of development.
# - Trade and hospitality bussiness should be promoted further.
# - Manufacturing should be further promoted.
#
# Category II: 'Arunachal Pradesh', 'Punjab','Telangana', 'Gujarat', 'Karnataka', 'Tamil Nadu','Maharashtra', 'Uttarakhand'
# - These states have relatively good per capita gsdp and are driven by around equal percentage by industries and agriculture. This implies that the these states already have pool of talent to drive industries and agriculture. Because of the talent, other industies can take their advantage and set up good industries.
# - States like Karnataka, Tamil Nadu, Gujarat and Maharashtra, which has huge costal area can set up ports. Costal area can help in harness clean energy and fisheries can be increased. Similary, tourism industy should also be encouraged.
#
# Category III:  'Madhya Pradesh', 'Odisha', 'Meghalaya', 'Tripura', 'Rajasthan', 'Chhattisgarh', 'Nagaland', 'Andhra Pradesh'
# - These states are mostly dependent on agriculture and have less number of industries. More programs for educating the youth and promoted which can lead to futher developement of industries.
# - As these states are driven by agriculture, more investment should be done on modern ways of agriculture to increase the productivity of the crops.
# - For states like Andhra Pradesh and Odissa, ports should be developed for the transport of goods which will create new source of employement and also will increase the trade for produced goods.
# - North Indian states like Meghalaya, Tripura and Nagaland  lies in this category. As these states are also driven by agriculture and their population density is also less, which implies points to the lack of good infrastructure for their produced goods. Steps must be taken to connect these states to the whole of India and more industries must be set up.
#
# Category IV: 'Bihar', 'Uttar Pradesh', 'Manipur' 'Assam', 'Jharkhand'.
# Most of the population in these are dependent on agriculture and manufacturing lies at the 6th category. Since the economy is dependent on agriculture, recommendation are:
# - Increase the productivity of the crops by being less dependent on rainfall and more on water sources like canal or underground water. Also, better infrastructure must be developed to preserve the agricultural products for long duration of time.
# - Better infrastructure in terms of connectivity must be developed to transport the goods and products from agriculture. If better infrastructure is developed to store the goods, farmers can get better prices for their crops as they do not need to sell their products at cheaper prices if the productivity is high.
# - Industries should be set up for these states. This in turn will help the population to be less dependent on agriculture and help to generate a steady income throughout the year. There should be gradual shift from agriculture to industries.
# - States like Bihar, Uttar Pradesh, Assam have rivers like Ganga, Yamuna, Narmada and Brahmaputra which can be used for cheaper water transport.

# %% [markdown]
# # Part II

# %% [markdown]
# # Analysing Drop-out Rate

# %%
drop_out_rate = pd.read_csv('rs_session243_au570_1.1.csv')
drop_out_rate
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# 14         15          Jammu and Kashmir                 6.30
# 15         16                  Jharkhand                 7.21
# 16         17                  Karnataka                 2.97
# 17         18                     Kerala                  NaN
# 18         19                Lakshadweep                 2.50
# 19         20             Madhya Pradesh                 6.11
# 20         21                Maharashtra                 0.97
# 21         22                    Manipur                 9.86
# 22         23                  Meghalaya                10.14
# 23         24                    Mizoram                24.11
# 24         25                   Nagaland                 7.07
# 25         26                     Odisha                 3.56
# 26         27                 Puducherry                 0.34
# 27         28                     Punjab                 1.99
# 28         29                  Rajasthan                 7.97
# 29         30                     Sikkim                 3.60
# 30         31                 Tamil Nadu                 4.06
# 31         32                  Telangana                  NaN
# 32         33                    Tripura                 2.22
# 33         34              Uttar Pradesh                10.28
# 34         35                 Uttrakhand                 1.16
# 35         36                West Bengal                 6.30
# 36  All India                  All India                 4.67
#
#     Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                  1.21                   0.51                       1.23
# 1                  4.35                   6.72                       3.36
# 2                 10.89                  10.82                       7.47
# 3                  7.44                  15.36                       7.20
# 4                  2.09                    NaN                        NaN
# 5                   NaN                    NaN                       0.10
# 6                  1.42                   2.91                       5.42
# 7                  1.57                   1.47                       3.38
# 8                  0.85                   1.11                        NaN
# 9                   NaN                    NaN                        NaN
# 10                 0.20                   0.73                        NaN
# 11                 0.76                   0.89                       5.20
# 12                 0.41                   5.61                       0.46
# 13                 0.46                   0.64                       0.51
# 14                 5.46                   6.79                       5.52
# 15                 6.41                   5.48                       5.47
# 16                 2.32                   2.02                       5.05
# 17                  NaN                    NaN                        NaN
# 18                  NaN                    NaN                       0.29
# 19                10.14                   6.59                       8.53
# 20                 0.55                   1.26                       1.74
# 21                18.00                   9.66                       6.06
# 22                10.34                   9.46                       7.85
# 23                12.96                  10.10                      19.28
# 24                19.41                   5.61                       9.83
# 25                 2.94                   2.86                       3.81
# 26                 0.66                   0.37                       0.68
# 27                 1.29                   3.05                       2.78
# 28                 8.39                   5.02                       4.42
# 29                 4.57                   2.27                       3.15
# 30                 0.46                    NaN                       1.24
# 31                 5.81                   2.08                        NaN
# 32                 3.58                   1.28                       3.08
# 33                 7.08                   8.58                       1.06
# 34                 3.07                   4.04                       0.13
# 35                 2.91                   1.47                       5.18
# 36                 4.34                   4.13                       3.13
#
#     Upper Primary - 2013-2014  Upper Primary - 2014-2015  \
# 0                        0.51                       1.69
# 1                        3.78                       5.20
# 2                        5.59                       6.71
# 3                        7.05                      10.51
# 4                        2.98                       4.08
# 5                        1.08                       0.44
# 6                        3.80                       5.85
# 7                        4.13                       4.02
# 8                        3.58                       3.11
# 9                        2.78                       0.76
# 10                        NaN                       0.07
# 11                       5.55                       6.41
# 12                       2.55                       5.81
# 13                       0.78                       0.87
# 14                       4.30                       5.44
# 15                       7.42                       8.99
# 16                       2.51                       3.85
# 17                        NaN                        NaN
# 18                       1.86                       2.78
# 19                      11.70                       9.20
# 20                       0.61                       1.79
# 21                       7.02                       4.20
# 22                       6.84                       6.52
# 23                       6.02                       4.78
# 24                      17.86                       7.92
# 25                       2.80                       3.81
# 26                       0.60                       0.56
# 27                       2.85                       3.22
# 28                       6.03                       3.07
# 29                       5.14                       1.57
# 30                       4.52                        NaN
# 31                       4.71                       2.30
# 32                       2.72                       1.99
# 33                       0.53                       2.70
# 34                       1.68                       1.19
# 35                       4.31                       4.30
# 36                       3.77                       4.03
#
#     Secondary - 2012-2013  Secondary - 2013-2014  Secondary - 2014-2015  \
# 0                    5.56                   7.20                  9.870
# 1                   12.72                  12.65                 15.710
# 2                   12.93                  14.49                 17.110
# 3                   26.77                  30.43                 27.060
# 4                   30.14                  25.33                 25.900
# 5                     NaN                    NaN                    NaN
# 6                   14.86                  23.41                 21.260
# 7                   24.41                  28.59                 16.770
# 8                   11.52                  19.86                 32.270
# 9                    5.32                   8.90                 11.810
# 10                   7.96                   9.58                 11.150
# 11                  13.55                  21.61                 25.040
# 12                   8.98                  12.51                 15.890
# 13                   8.37                   9.09                  6.070
# 14                  17.33                  15.36                 17.280
# 15                  18.50                  23.15                 24.000
# 16                  39.92                  27.57                 26.180
# 17                   9.45                  14.46                 12.320
# 18                   7.68                   8.03                  6.763
# 19                  13.63                  26.47                 24.770
# 20                  16.20                  14.47                 12.870
# 21                   9.75                  13.81                 14.380
# 22                  26.03                  24.75                 20.520
# 23                  21.42                  18.70                 21.880
# 24                  26.51                  35.11                 18.230
# 25                  49.86                  49.48                 29.560
# 26                  15.21                  14.24                 12.190
# 27                   9.80                   8.83                  8.860
# 28                  13.65                  18.77                 13.480
# 29                   9.23                  12.89                 15.890
# 30                  10.20                  12.20                  8.100
# 31                    NaN                  17.43                 15.530
# 32                  25.50                  25.09                 28.420
# 33                    NaN                   7.30                 10.220
# 34                   9.68                   8.70                 10.400
# 35                  17.30                  18.34                 17.800
# 36                  14.54                  17.86                 17.060
#
#     Senior Secondary - 2012-2013  Senior Secondary - 2013-2014  \
# 0                          14.14                         15.87
# 1                           0.35                         11.79
# 2                           5.11                         17.07
# 3                           4.69                          7.24
# 4                            NaN                           NaN
# 5                          13.65                         11.28
# 6                            NaN                           NaN
# 7                           9.65                          6.24
# 8                           1.26                          9.86
# 9                          14.47                         16.25
# 10                         11.26                         13.36
# 11                          0.46                          7.83
# 12                           NaN                          2.18
# 13                          9.02                          7.07
# 14                         10.66                          7.64
# 15                           NaN                           NaN
# 16                         15.33                           NaN
# 17                           NaN                          6.40
# 18                          6.59                          2.82
# 19                           NaN                          1.55
# 20                          3.20                          3.34
# 21                          7.93                          3.20
# 22                           NaN                           NaN
# 23                           NaN                           NaN
# 24                         18.29                         14.19
# 25                           NaN                           NaN
# 26                          5.25                         11.16
# 27                          8.28                          5.81
# 28                           NaN                           NaN
# 29                          8.10                         12.91
# 30                          1.87                          4.44
# 31                           NaN                         13.43
# 32                          8.87                          9.11
# 33                           NaN                           NaN
# 34                          1.59                           NaN
# 35                          8.13                          7.90
# 36                           NaN                          1.54
#
#     Senior Secondary - 2014-2015
# 0                          16.93
# 1                            NaN
# 2                          18.42
# 3                            NaN
# 4                            NaN
# 5                          10.55
# 6                           2.76
# 7                           9.47
# 8                          40.48
# 9                          17.32
# 10                         13.91
# 11                          7.04
# 12                          5.75
# 13                          7.41
# 14                         12.65
# 15                          3.41
# 16                          1.96
# 17                          0.47
# 18                          3.12
# 19                           NaN
# 20                          1.83
# 21                           NaN
# 22                           NaN
# 23                          6.91
# 24                          6.97
# 25                           NaN
# 26                          4.50
# 27                          5.83
# 28                           NaN
# 29                         11.76
# 30                          3.41
# 31                          0.77
# 32                          8.93
# 33                          2.10
# 34                          3.01
# 35                          8.11
# 36                           NaN

# %%
drop_out_rate.rename(columns={'Level of Education - State': 'state'}, inplace=True)

# %%
drop_out_rate['state'].replace({'A & N Islands': 'Andaman & Nicobar Islands', 'All India': 'All_India GDP', 'West Bengal': 'West Bengal1',
                                'Uttrakhand': 'Uttarakhand', 'Chhatisgarh':'Chhattisgarh' }, inplace=True)

# %%
drop_out_rate = drop_out_rate.set_index('state')
drop_out_rate
# Out:
#                              Sl. No.  Primary - 2012-2013  \
# state
# Andaman & Nicobar Islands          1                 0.68
# Andhra Pradesh                     2                 3.18
# Arunachal Pradesh                  3                15.16
# Assam                              4                 6.24
# Bihar                              5                  NaN
# Chandigarh                         6                  NaN
# Chhattisgarh                       7                 4.14
# Dadra & Nagar Haveli               8                  NaN
# Daman & Diu                        9                  NaN
# Delhi                             10                  NaN
# Goa                               11                  NaN
# Gujarat                           12                 0.74
# Haryana                           13                 1.29
# Himachal Pradesh                  14                 0.45
# Jammu and Kashmir                 15                 6.30
# Jharkhand                         16                 7.21
# Karnataka                         17                 2.97
# Kerala                            18                  NaN
# Lakshadweep                       19                 2.50
# Madhya Pradesh                    20                 6.11
# Maharashtra                       21                 0.97
# Manipur                           22                 9.86
# Meghalaya                         23                10.14
# Mizoram                           24                24.11
# Nagaland                          25                 7.07
# Odisha                            26                 3.56
# Puducherry                        27                 0.34
# Punjab                            28                 1.99
# Rajasthan                         29                 7.97
# Sikkim                            30                 3.60
# Tamil Nadu                        31                 4.06
# Telangana                         32                  NaN
# Tripura                           33                 2.22
# Uttar Pradesh                     34                10.28
# Uttarakhand                       35                 1.16
# West Bengal1                      36                 6.30
# All_India GDP              All India                 4.67
#
#                            Primary - 2014-2015  Primary - 2014-2015.1  \
# state
# Andaman & Nicobar Islands                 1.21                   0.51
# Andhra Pradesh                            4.35                   6.72
# Arunachal Pradesh                        10.89                  10.82
# Assam                                     7.44                  15.36
# Bihar                                     2.09                    NaN
# Chandigarh                                 NaN                    NaN
# Chhattisgarh                              1.42                   2.91
# Dadra & Nagar Haveli                      1.57                   1.47
# Daman & Diu                               0.85                   1.11
# Delhi                                      NaN                    NaN
# Goa                                       0.20                   0.73
# Gujarat                                   0.76                   0.89
# Haryana                                   0.41                   5.61
# Himachal Pradesh                          0.46                   0.64
# Jammu and Kashmir                         5.46                   6.79
# Jharkhand                                 6.41                   5.48
# Karnataka                                 2.32                   2.02
# Kerala                                     NaN                    NaN
# Lakshadweep                                NaN                    NaN
# Madhya Pradesh                           10.14                   6.59
# Maharashtra                               0.55                   1.26
# Manipur                                  18.00                   9.66
# Meghalaya                                10.34                   9.46
# Mizoram                                  12.96                  10.10
# Nagaland                                 19.41                   5.61
# Odisha                                    2.94                   2.86
# Puducherry                                0.66                   0.37
# Punjab                                    1.29                   3.05
# Rajasthan                                 8.39                   5.02
# Sikkim                                    4.57                   2.27
# Tamil Nadu                                0.46                    NaN
# Telangana                                 5.81                   2.08
# Tripura                                   3.58                   1.28
# Uttar Pradesh                             7.08                   8.58
# Uttarakhand                               3.07                   4.04
# West Bengal1                              2.91                   1.47
# All_India GDP                             4.34                   4.13
#
#                            Upper Primary - 2012-2013  \
# state
# Andaman & Nicobar Islands                       1.23
# Andhra Pradesh                                  3.36
# Arunachal Pradesh                               7.47
# Assam                                           7.20
# Bihar                                            NaN
# Chandigarh                                      0.10
# Chhattisgarh                                    5.42
# Dadra & Nagar Haveli                            3.38
# Daman & Diu                                      NaN
# Delhi                                            NaN
# Goa                                              NaN
# Gujarat                                         5.20
# Haryana                                         0.46
# Himachal Pradesh                                0.51
# Jammu and Kashmir                               5.52
# Jharkhand                                       5.47
# Karnataka                                       5.05
# Kerala                                           NaN
# Lakshadweep                                     0.29
# Madhya Pradesh                                  8.53
# Maharashtra                                     1.74
# Manipur                                         6.06
# Meghalaya                                       7.85
# Mizoram                                        19.28
# Nagaland                                        9.83
# Odisha                                          3.81
# Puducherry                                      0.68
# Punjab                                          2.78
# Rajasthan                                       4.42
# Sikkim                                          3.15
# Tamil Nadu                                      1.24
# Telangana                                        NaN
# Tripura                                         3.08
# Uttar Pradesh                                   1.06
# Uttarakhand                                     0.13
# West Bengal1                                    5.18
# All_India GDP                                   3.13
#
#                            Upper Primary - 2013-2014  \
# state
# Andaman & Nicobar Islands                       0.51
# Andhra Pradesh                                  3.78
# Arunachal Pradesh                               5.59
# Assam                                           7.05
# Bihar                                           2.98
# Chandigarh                                      1.08
# Chhattisgarh                                    3.80
# Dadra & Nagar Haveli                            4.13
# Daman & Diu                                     3.58
# Delhi                                           2.78
# Goa                                              NaN
# Gujarat                                         5.55
# Haryana                                         2.55
# Himachal Pradesh                                0.78
# Jammu and Kashmir                               4.30
# Jharkhand                                       7.42
# Karnataka                                       2.51
# Kerala                                           NaN
# Lakshadweep                                     1.86
# Madhya Pradesh                                 11.70
# Maharashtra                                     0.61
# Manipur                                         7.02
# Meghalaya                                       6.84
# Mizoram                                         6.02
# Nagaland                                       17.86
# Odisha                                          2.80
# Puducherry                                      0.60
# Punjab                                          2.85
# Rajasthan                                       6.03
# Sikkim                                          5.14
# Tamil Nadu                                      4.52
# Telangana                                       4.71
# Tripura                                         2.72
# Uttar Pradesh                                   0.53
# Uttarakhand                                     1.68
# West Bengal1                                    4.31
# All_India GDP                                   3.77
#
#                            Upper Primary - 2014-2015  Secondary - 2012-2013  \
# state
# Andaman & Nicobar Islands                       1.69                   5.56
# Andhra Pradesh                                  5.20                  12.72
# Arunachal Pradesh                               6.71                  12.93
# Assam                                          10.51                  26.77
# Bihar                                           4.08                  30.14
# Chandigarh                                      0.44                    NaN
# Chhattisgarh                                    5.85                  14.86
# Dadra & Nagar Haveli                            4.02                  24.41
# Daman & Diu                                     3.11                  11.52
# Delhi                                           0.76                   5.32
# Goa                                             0.07                   7.96
# Gujarat                                         6.41                  13.55
# Haryana                                         5.81                   8.98
# Himachal Pradesh                                0.87                   8.37
# Jammu and Kashmir                               5.44                  17.33
# Jharkhand                                       8.99                  18.50
# Karnataka                                       3.85                  39.92
# Kerala                                           NaN                   9.45
# Lakshadweep                                     2.78                   7.68
# Madhya Pradesh                                  9.20                  13.63
# Maharashtra                                     1.79                  16.20
# Manipur                                         4.20                   9.75
# Meghalaya                                       6.52                  26.03
# Mizoram                                         4.78                  21.42
# Nagaland                                        7.92                  26.51
# Odisha                                          3.81                  49.86
# Puducherry                                      0.56                  15.21
# Punjab                                          3.22                   9.80
# Rajasthan                                       3.07                  13.65
# Sikkim                                          1.57                   9.23
# Tamil Nadu                                       NaN                  10.20
# Telangana                                       2.30                    NaN
# Tripura                                         1.99                  25.50
# Uttar Pradesh                                   2.70                    NaN
# Uttarakhand                                     1.19                   9.68
# West Bengal1                                    4.30                  17.30
# All_India GDP                                   4.03                  14.54
#
#                            Secondary - 2013-2014  Secondary - 2014-2015  \
# state
# Andaman & Nicobar Islands                   7.20                  9.870
# Andhra Pradesh                             12.65                 15.710
# Arunachal Pradesh                          14.49                 17.110
# Assam                                      30.43                 27.060
# Bihar                                      25.33                 25.900
# Chandigarh                                   NaN                    NaN
# Chhattisgarh                               23.41                 21.260
# Dadra & Nagar Haveli                       28.59                 16.770
# Daman & Diu                                19.86                 32.270
# Delhi                                       8.90                 11.810
# Goa                                         9.58                 11.150
# Gujarat                                    21.61                 25.040
# Haryana                                    12.51                 15.890
# Himachal Pradesh                            9.09                  6.070
# Jammu and Kashmir                          15.36                 17.280
# Jharkhand                                  23.15                 24.000
# Karnataka                                  27.57                 26.180
# Kerala                                     14.46                 12.320
# Lakshadweep                                 8.03                  6.763
# Madhya Pradesh                             26.47                 24.770
# Maharashtra                                14.47                 12.870
# Manipur                                    13.81                 14.380
# Meghalaya                                  24.75                 20.520
# Mizoram                                    18.70                 21.880
# Nagaland                                   35.11                 18.230
# Odisha                                     49.48                 29.560
# Puducherry                                 14.24                 12.190
# Punjab                                      8.83                  8.860
# Rajasthan                                  18.77                 13.480
# Sikkim                                     12.89                 15.890
# Tamil Nadu                                 12.20                  8.100
# Telangana                                  17.43                 15.530
# Tripura                                    25.09                 28.420
# Uttar Pradesh                               7.30                 10.220
# Uttarakhand                                 8.70                 10.400
# West Bengal1                               18.34                 17.800
# All_India GDP                              17.86                 17.060
#
#                            Senior Secondary - 2012-2013  \
# state
# Andaman & Nicobar Islands                         14.14
# Andhra Pradesh                                     0.35
# Arunachal Pradesh                                  5.11
# Assam                                              4.69
# Bihar                                               NaN
# Chandigarh                                        13.65
# Chhattisgarh                                        NaN
# Dadra & Nagar Haveli                               9.65
# Daman & Diu                                        1.26
# Delhi                                             14.47
# Goa                                               11.26
# Gujarat                                            0.46
# Haryana                                             NaN
# Himachal Pradesh                                   9.02
# Jammu and Kashmir                                 10.66
# Jharkhand                                           NaN
# Karnataka                                         15.33
# Kerala                                              NaN
# Lakshadweep                                        6.59
# Madhya Pradesh                                      NaN
# Maharashtra                                        3.20
# Manipur                                            7.93
# Meghalaya                                           NaN
# Mizoram                                             NaN
# Nagaland                                          18.29
# Odisha                                              NaN
# Puducherry                                         5.25
# Punjab                                             8.28
# Rajasthan                                           NaN
# Sikkim                                             8.10
# Tamil Nadu                                         1.87
# Telangana                                           NaN
# Tripura                                            8.87
# Uttar Pradesh                                       NaN
# Uttarakhand                                        1.59
# West Bengal1                                       8.13
# All_India GDP                                       NaN
#
#                            Senior Secondary - 2013-2014  \
# state
# Andaman & Nicobar Islands                         15.87
# Andhra Pradesh                                    11.79
# Arunachal Pradesh                                 17.07
# Assam                                              7.24
# Bihar                                               NaN
# Chandigarh                                        11.28
# Chhattisgarh                                        NaN
# Dadra & Nagar Haveli                               6.24
# Daman & Diu                                        9.86
# Delhi                                             16.25
# Goa                                               13.36
# Gujarat                                            7.83
# Haryana                                            2.18
# Himachal Pradesh                                   7.07
# Jammu and Kashmir                                  7.64
# Jharkhand                                           NaN
# Karnataka                                           NaN
# Kerala                                             6.40
# Lakshadweep                                        2.82
# Madhya Pradesh                                     1.55
# Maharashtra                                        3.34
# Manipur                                            3.20
# Meghalaya                                           NaN
# Mizoram                                             NaN
# Nagaland                                          14.19
# Odisha                                              NaN
# Puducherry                                        11.16
# Punjab                                             5.81
# Rajasthan                                           NaN
# Sikkim                                            12.91
# Tamil Nadu                                         4.44
# Telangana                                         13.43
# Tripura                                            9.11
# Uttar Pradesh                                       NaN
# Uttarakhand                                         NaN
# West Bengal1                                       7.90
# All_India GDP                                      1.54
#
#                            Senior Secondary - 2014-2015
# state
# Andaman & Nicobar Islands                         16.93
# Andhra Pradesh                                      NaN
# Arunachal Pradesh                                 18.42
# Assam                                               NaN
# Bihar                                               NaN
# Chandigarh                                        10.55
# Chhattisgarh                                       2.76
# Dadra & Nagar Haveli                               9.47
# Daman & Diu                                       40.48
# Delhi                                             17.32
# Goa                                               13.91
# Gujarat                                            7.04
# Haryana                                            5.75
# Himachal Pradesh                                   7.41
# Jammu and Kashmir                                 12.65
# Jharkhand                                          3.41
# Karnataka                                          1.96
# Kerala                                             0.47
# Lakshadweep                                        3.12
# Madhya Pradesh                                      NaN
# Maharashtra                                        1.83
# Manipur                                             NaN
# Meghalaya                                           NaN
# Mizoram                                            6.91
# Nagaland                                           6.97
# Odisha                                              NaN
# Puducherry                                         4.50
# Punjab                                             5.83
# Rajasthan                                           NaN
# Sikkim                                            11.76
# Tamil Nadu                                         3.41
# Telangana                                          0.77
# Tripura                                            8.93
# Uttar Pradesh                                      2.10
# Uttarakhand                                        3.01
# West Bengal1                                       8.11
# All_India GDP                                       NaN

# %%
gsva_drop = pd.merge(gsva, drop_out_rate, left_index=True, right_index=True, how='inner')

# %%
gsva_drop
# Out:
#                   Agriculture, forestry and fishing Air transport  \
# state
# Bihar                                       7951890         13599
# Uttar Pradesh                              25097754         36582
# Manipur                                      383140          6288
# Assam                                       3855548         26223
# Jharkhand                                   3211065          6716
# Madhya Pradesh                             16235647         26746
# Odisha                                      6422978         15354
# Meghalaya                                    366521          1443
# Tripura                                      799825           NaN
# Rajasthan                                  15044394         13469
# Chhattisgarh                                3948847          9507
# Nagaland                                     607897          4153
# Andhra Pradesh                             14819416         14900
# Arunachal Pradesh                            686117             0
# Punjab                                      9285716          4473
# Telangana                                   7591501        120691
# Gujarat                                   1.377e+07           NaN
# Karnataka                                  11219422        171785
# Tamil Nadu                                 13064238        180836
# Maharashtra                                16475655        174188
# Uttarakhand                             1.60142e+06          3889
# Kerala                                      5930617        125029
# Haryana                                 8.01524e+06           NaN
# Sikkim                                       137447             0
# Goa                                          308507         46359
#
#                   Communication & services related to broadcasting  \
# state
# Bihar                                                       919427
# Uttar Pradesh                                              1914737
# Manipur                                                      42017
# Assam                                                       357619
# Jharkhand                                                   323214
# Madhya Pradesh                                              905381
# Odisha                                                      513531
# Meghalaya                                                    40547
# Tripura                                                      66676
# Rajasthan                                                  1150955
# Chhattisgarh                                                294552
# Nagaland                                                     37794
# Andhra Pradesh                                              928756
# Arunachal Pradesh                                            19568
# Punjab                                                      660819
# Telangana                                                   753992
# Gujarat                                                1.24252e+06
# Karnataka                                                  1349520
# Tamil Nadu                                                 1903283
# Maharashtra                                                2551115
# Uttarakhand                                                 733778
# Kerala                                                      884767
# Haryana                                                     479658
# Sikkim                                                       12064
# Goa                                                          44028
#
#                   Construction        Crops  \
# state
# Bihar                  3449763      4688237
# Uttar Pradesh         11256450     16215212
# Manipur                 143182       226583
# Assam                  1733568      2890544
# Jharkhand              1789834      2094466
# Madhya Pradesh         4403151     13216013
# Odisha                 2402396      4382636
# Meghalaya               150256       223330
# Tripura                 177899       397591
# Rajasthan              5353326      7673441
# Chhattisgarh           2669855      2613371
# Nagaland                156072       375825
# Andhra Pradesh         4664889      7893514
# Arunachal Pradesh       147842       415520
# Punjab                 2202962      5690972
# Telangana              2854024      4162493
# Gujarat            5.52602e+06  9.67109e+06
# Karnataka              6104799      8157179
# Tamil Nadu            12216718      7297820
# Maharashtra            9450211     10435121
# Uttarakhand        1.34273e+06       866146
# Kerala                 7314003      3070386
# Haryana            3.70257e+06  4.63673e+06
# Sikkim                   82058       114976
# Goa                     165819       140421
#
#                   Electricity, gas, water supply & other utility services  \
# state
# Bihar                                                         345168
# Uttar Pradesh                                                2030625
# Manipur                                                        27490
# Assam                                                         296587
# Jharkhand                                                     337489
# Madhya Pradesh                                               1272905
# Odisha                                                        833067
# Meghalaya                                                      54473
# Tripura                                                        77870
# Rajasthan                                                    1122888
# Chhattisgarh                                                 1198438
# Nagaland                                                       37944
# Andhra Pradesh                                               1151729
# Arunachal Pradesh                                             113527
# Punjab                                                        911611
# Telangana                                                     716266
# Gujarat                                                  3.40998e+06
# Karnataka                                                    1425762
# Tamil Nadu                                                   1710379
# Maharashtra                                                  4334702
# Uttarakhand                                                   433880
# Kerala                                                        482470
# Haryana                                                  1.10192e+06
# Sikkim                                                        212499
# Goa                                                           204110
#
#                   Financial services Fishing and aquaculture  \
# state
# Bihar                        1178022                  653224
# Uttar Pradesh                3392275                  380730
# Manipur                        30315                   35243
# Assam                         543651                  529539
# Jharkhand                     551441                  108947
# Madhya Pradesh               1988794                  121277
# Odisha                       1065147                  460636
# Meghalaya                      64091                    9583
# Tripura                        86094                  168961
# Rajasthan                    1827413                   58036
# Chhattisgarh                  739057                  385483
# Nagaland                       60393                    8470
# Andhra Pradesh               1900863                 2270664
# Arunachal Pradesh              25207                    8193
# Punjab                       2057520                  107657
# Telangana                    3023729                  266968
# Gujarat                  4.60664e+06                  638357
# Karnataka                    4094169                  500390
# Tamil Nadu                   5598498                  680352
# Maharashtra                 16143324                  475141
# Uttarakhand                   385030                    4796
# Kerala                       2010306                  704319
# Haryana                  1.67149e+06                  110080
# Sikkim                         21079                     604
# Goa                           233618                  122201
#
#                   Forestry and logging Gross State Domestic Product  \
# state
# Bihar                           550132                     37391988
# Uttar Pradesh                  1404936                    104337115
# Manipur                          45831                  1.80428e+06
# Assam                           261987                     19809800
# Jharkhand                       445149                     21710718
# Madhya Pradesh                  965588                     48198169
# Odisha                          791463                     32197092
# Meghalaya                        61166                  2.44081e+06
# Tripura                         145096                  2.96666e+06
# Rajasthan                      1956660                     61219447
# Chhattisgarh                    597785                     23498180
# Nagaland                         99802                      1841424
# Andhra Pradesh                  346160                     52646842
# Arunachal Pradesh               224017                      1676119
# Punjab                          848245                     36801089
# Telangana                       210741                     51117765
# Gujarat                         761616                  8.95027e+07
# Karnataka                       693082                     92178806
# Tamil Nadu                      392705                    109256373
# Maharashtra                    1592564                    179212165
# Uttarakhand                     339293                  1.61985e+07
# Kerala                          499808                     52600230
# Haryana                         352254                  4.37462e+07
# Sikkim                            4529                      1520933
# Goa                              15744                      4063307
#
#                               ...              Primary - 2014-2015.1  \
# state                         ...
# Bihar                         ...                                NaN
# Uttar Pradesh                 ...                               8.58
# Manipur                       ...                               9.66
# Assam                         ...                              15.36
# Jharkhand                     ...                               5.48
# Madhya Pradesh                ...                               6.59
# Odisha                        ...                               2.86
# Meghalaya                     ...                               9.46
# Tripura                       ...                               1.28
# Rajasthan                     ...                               5.02
# Chhattisgarh                  ...                               2.91
# Nagaland                      ...                               5.61
# Andhra Pradesh                ...                               6.72
# Arunachal Pradesh             ...                              10.82
# Punjab                        ...                               3.05
# Telangana                     ...                               2.08
# Gujarat                       ...                               0.89
# Karnataka                     ...                               2.02
# Tamil Nadu                    ...                                NaN
# Maharashtra                   ...                               1.26
# Uttarakhand                   ...                               4.04
# Kerala                        ...                                NaN
# Haryana                       ...                               5.61
# Sikkim                        ...                               2.27
# Goa                           ...                               0.73
#
#                   Upper Primary - 2012-2013 Upper Primary - 2013-2014  \
# state
# Bihar                                   NaN                      2.98
# Uttar Pradesh                          1.06                      0.53
# Manipur                                6.06                      7.02
# Assam                                  7.20                      7.05
# Jharkhand                              5.47                      7.42
# Madhya Pradesh                         8.53                     11.70
# Odisha                                 3.81                      2.80
# Meghalaya                              7.85                      6.84
# Tripura                                3.08                      2.72
# Rajasthan                              4.42                      6.03
# Chhattisgarh                           5.42                      3.80
# Nagaland                               9.83                     17.86
# Andhra Pradesh                         3.36                      3.78
# Arunachal Pradesh                      7.47                      5.59
# Punjab                                 2.78                      2.85
# Telangana                               NaN                      4.71
# Gujarat                                5.20                      5.55
# Karnataka                              5.05                      2.51
# Tamil Nadu                             1.24                      4.52
# Maharashtra                            1.74                      0.61
# Uttarakhand                            0.13                      1.68
# Kerala                                  NaN                       NaN
# Haryana                                0.46                      2.55
# Sikkim                                 3.15                      5.14
# Goa                                     NaN                       NaN
#
#                   Upper Primary - 2014-2015 Secondary - 2012-2013  \
# state
# Bihar                                  4.08                 30.14
# Uttar Pradesh                          2.70                   NaN
# Manipur                                4.20                  9.75
# Assam                                 10.51                 26.77
# Jharkhand                              8.99                 18.50
# Madhya Pradesh                         9.20                 13.63
# Odisha                                 3.81                 49.86
# Meghalaya                              6.52                 26.03
# Tripura                                1.99                 25.50
# Rajasthan                              3.07                 13.65
# Chhattisgarh                           5.85                 14.86
# Nagaland                               7.92                 26.51
# Andhra Pradesh                         5.20                 12.72
# Arunachal Pradesh                      6.71                 12.93
# Punjab                                 3.22                  9.80
# Telangana                              2.30                   NaN
# Gujarat                                6.41                 13.55
# Karnataka                              3.85                 39.92
# Tamil Nadu                              NaN                 10.20
# Maharashtra                            1.79                 16.20
# Uttarakhand                            1.19                  9.68
# Kerala                                  NaN                  9.45
# Haryana                                5.81                  8.98
# Sikkim                                 1.57                  9.23
# Goa                                    0.07                  7.96
#
#                   Secondary - 2013-2014 Secondary - 2014-2015  \
# state
# Bihar                             25.33                 25.90
# Uttar Pradesh                      7.30                 10.22
# Manipur                           13.81                 14.38
# Assam                             30.43                 27.06
# Jharkhand                         23.15                 24.00
# Madhya Pradesh                    26.47                 24.77
# Odisha                            49.48                 29.56
# Meghalaya                         24.75                 20.52
# Tripura                           25.09                 28.42
# Rajasthan                         18.77                 13.48
# Chhattisgarh                      23.41                 21.26
# Nagaland                          35.11                 18.23
# Andhra Pradesh                    12.65                 15.71
# Arunachal Pradesh                 14.49                 17.11
# Punjab                             8.83                  8.86
# Telangana                         17.43                 15.53
# Gujarat                           21.61                 25.04
# Karnataka                         27.57                 26.18
# Tamil Nadu                        12.20                  8.10
# Maharashtra                       14.47                 12.87
# Uttarakhand                        8.70                 10.40
# Kerala                            14.46                 12.32
# Haryana                           12.51                 15.89
# Sikkim                            12.89                 15.89
# Goa                                9.58                 11.15
#
#                   Senior Secondary - 2012-2013 Senior Secondary - 2013-2014  \
# state
# Bihar                                      NaN                          NaN
# Uttar Pradesh                              NaN                          NaN
# Manipur                                   7.93                         3.20
# Assam                                     4.69                         7.24
# Jharkhand                                  NaN                          NaN
# Madhya Pradesh                             NaN                         1.55
# Odisha                                     NaN                          NaN
# Meghalaya                                  NaN                          NaN
# Tripura                                   8.87                         9.11
# Rajasthan                                  NaN                          NaN
# Chhattisgarh                               NaN                          NaN
# Nagaland                                 18.29                        14.19
# Andhra Pradesh                            0.35                        11.79
# Arunachal Pradesh                         5.11                        17.07
# Punjab                                    8.28                         5.81
# Telangana                                  NaN                        13.43
# Gujarat                                   0.46                         7.83
# Karnataka                                15.33                          NaN
# Tamil Nadu                                1.87                         4.44
# Maharashtra                               3.20                         3.34
# Uttarakhand                               1.59                          NaN
# Kerala                                     NaN                         6.40
# Haryana                                    NaN                         2.18
# Sikkim                                    8.10                        12.91
# Goa                                      11.26                        13.36
#
#                   Senior Secondary - 2014-2015
# state
# Bihar                                      NaN
# Uttar Pradesh                             2.10
# Manipur                                    NaN
# Assam                                      NaN
# Jharkhand                                 3.41
# Madhya Pradesh                             NaN
# Odisha                                     NaN
# Meghalaya                                  NaN
# Tripura                                   8.93
# Rajasthan                                  NaN
# Chhattisgarh                              2.76
# Nagaland                                  6.97
# Andhra Pradesh                             NaN
# Arunachal Pradesh                        18.42
# Punjab                                    5.83
# Telangana                                 0.77
# Gujarat                                   7.04
# Karnataka                                 1.96
# Tamil Nadu                                3.41
# Maharashtra                               1.83
# Uttarakhand                               3.01
# Kerala                                    0.47
# Haryana                                   5.75
# Sikkim                                   11.76
# Goa                                      13.91
#
# [25 rows x 53 columns]

# %%
gsva_drop.columns.values
# Out:
# array(['Agriculture, forestry and fishing', 'Air transport',
#        'Communication & services related to broadcasting', 'Construction',
#        'Crops', 'Electricity, gas, water supply & other utility services',
#        'Financial services', 'Fishing and aquaculture',
#        'Forestry and logging', 'Gross State Domestic Product',
#        'Hotels & restaurants', 'Livestock', 'Manufacturing',
#        'Mining and quarrying', 'Other services', 'Per Capita GSDP (Rs.)',
#        "Population ('00)", 'Primary', 'Public administration', 'Railways',
#        'Real estate, ownership of dwelling & professional services',
#        'Road transport', 'Road transport*', 'Road transport**',
#        'Secondary', 'Services incidental to transport',
#        'Services incidental to transport*', 'Storage',
#        'Subsidies on products', 'TOTAL GSVA at basic prices',
#        'Taxes on Products', 'Tertiary', 'Trade & repair services',
#        'Trade & repair services*',
#        'Trade, repair, hotels and restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Water transport', 'primary_gdp_percent', 'secondary_gdp_percent',
#        'tertiary_gdp_percent', 'Sl. No.', 'Primary - 2012-2013',
#        'Primary - 2014-2015', 'Primary - 2014-2015.1',
#        'Upper Primary - 2012-2013', 'Upper Primary - 2013-2014',
#        'Upper Primary - 2014-2015', 'Secondary - 2012-2013',
#        'Secondary - 2013-2014', 'Secondary - 2014-2015',
#        'Senior Secondary - 2012-2013', 'Senior Secondary - 2013-2014',
#        'Senior Secondary - 2014-2015'], dtype=object)

# %%
gsva_drop
# Out:
#                   Agriculture, forestry and fishing Air transport  \
# state
# Bihar                                       7951890         13599
# Uttar Pradesh                              25097754         36582
# Manipur                                      383140          6288
# Assam                                       3855548         26223
# Jharkhand                                   3211065          6716
# Madhya Pradesh                             16235647         26746
# Odisha                                      6422978         15354
# Meghalaya                                    366521          1443
# Tripura                                      799825           NaN
# Rajasthan                                  15044394         13469
# Chhattisgarh                                3948847          9507
# Nagaland                                     607897          4153
# Andhra Pradesh                             14819416         14900
# Arunachal Pradesh                            686117             0
# Punjab                                      9285716          4473
# Telangana                                   7591501        120691
# Gujarat                                   1.377e+07           NaN
# Karnataka                                  11219422        171785
# Tamil Nadu                                 13064238        180836
# Maharashtra                                16475655        174188
# Uttarakhand                             1.60142e+06          3889
# Kerala                                      5930617        125029
# Haryana                                 8.01524e+06           NaN
# Sikkim                                       137447             0
# Goa                                          308507         46359
#
#                   Communication & services related to broadcasting  \
# state
# Bihar                                                       919427
# Uttar Pradesh                                              1914737
# Manipur                                                      42017
# Assam                                                       357619
# Jharkhand                                                   323214
# Madhya Pradesh                                              905381
# Odisha                                                      513531
# Meghalaya                                                    40547
# Tripura                                                      66676
# Rajasthan                                                  1150955
# Chhattisgarh                                                294552
# Nagaland                                                     37794
# Andhra Pradesh                                              928756
# Arunachal Pradesh                                            19568
# Punjab                                                      660819
# Telangana                                                   753992
# Gujarat                                                1.24252e+06
# Karnataka                                                  1349520
# Tamil Nadu                                                 1903283
# Maharashtra                                                2551115
# Uttarakhand                                                 733778
# Kerala                                                      884767
# Haryana                                                     479658
# Sikkim                                                       12064
# Goa                                                          44028
#
#                   Construction        Crops  \
# state
# Bihar                  3449763      4688237
# Uttar Pradesh         11256450     16215212
# Manipur                 143182       226583
# Assam                  1733568      2890544
# Jharkhand              1789834      2094466
# Madhya Pradesh         4403151     13216013
# Odisha                 2402396      4382636
# Meghalaya               150256       223330
# Tripura                 177899       397591
# Rajasthan              5353326      7673441
# Chhattisgarh           2669855      2613371
# Nagaland                156072       375825
# Andhra Pradesh         4664889      7893514
# Arunachal Pradesh       147842       415520
# Punjab                 2202962      5690972
# Telangana              2854024      4162493
# Gujarat            5.52602e+06  9.67109e+06
# Karnataka              6104799      8157179
# Tamil Nadu            12216718      7297820
# Maharashtra            9450211     10435121
# Uttarakhand        1.34273e+06       866146
# Kerala                 7314003      3070386
# Haryana            3.70257e+06  4.63673e+06
# Sikkim                   82058       114976
# Goa                     165819       140421
#
#                   Electricity, gas, water supply & other utility services  \
# state
# Bihar                                                         345168
# Uttar Pradesh                                                2030625
# Manipur                                                        27490
# Assam                                                         296587
# Jharkhand                                                     337489
# Madhya Pradesh                                               1272905
# Odisha                                                        833067
# Meghalaya                                                      54473
# Tripura                                                        77870
# Rajasthan                                                    1122888
# Chhattisgarh                                                 1198438
# Nagaland                                                       37944
# Andhra Pradesh                                               1151729
# Arunachal Pradesh                                             113527
# Punjab                                                        911611
# Telangana                                                     716266
# Gujarat                                                  3.40998e+06
# Karnataka                                                    1425762
# Tamil Nadu                                                   1710379
# Maharashtra                                                  4334702
# Uttarakhand                                                   433880
# Kerala                                                        482470
# Haryana                                                  1.10192e+06
# Sikkim                                                        212499
# Goa                                                           204110
#
#                   Financial services Fishing and aquaculture  \
# state
# Bihar                        1178022                  653224
# Uttar Pradesh                3392275                  380730
# Manipur                        30315                   35243
# Assam                         543651                  529539
# Jharkhand                     551441                  108947
# Madhya Pradesh               1988794                  121277
# Odisha                       1065147                  460636
# Meghalaya                      64091                    9583
# Tripura                        86094                  168961
# Rajasthan                    1827413                   58036
# Chhattisgarh                  739057                  385483
# Nagaland                       60393                    8470
# Andhra Pradesh               1900863                 2270664
# Arunachal Pradesh              25207                    8193
# Punjab                       2057520                  107657
# Telangana                    3023729                  266968
# Gujarat                  4.60664e+06                  638357
# Karnataka                    4094169                  500390
# Tamil Nadu                   5598498                  680352
# Maharashtra                 16143324                  475141
# Uttarakhand                   385030                    4796
# Kerala                       2010306                  704319
# Haryana                  1.67149e+06                  110080
# Sikkim                         21079                     604
# Goa                           233618                  122201
#
#                   Forestry and logging Gross State Domestic Product  \
# state
# Bihar                           550132                     37391988
# Uttar Pradesh                  1404936                    104337115
# Manipur                          45831                  1.80428e+06
# Assam                           261987                     19809800
# Jharkhand                       445149                     21710718
# Madhya Pradesh                  965588                     48198169
# Odisha                          791463                     32197092
# Meghalaya                        61166                  2.44081e+06
# Tripura                         145096                  2.96666e+06
# Rajasthan                      1956660                     61219447
# Chhattisgarh                    597785                     23498180
# Nagaland                         99802                      1841424
# Andhra Pradesh                  346160                     52646842
# Arunachal Pradesh               224017                      1676119
# Punjab                          848245                     36801089
# Telangana                       210741                     51117765
# Gujarat                         761616                  8.95027e+07
# Karnataka                       693082                     92178806
# Tamil Nadu                      392705                    109256373
# Maharashtra                    1592564                    179212165
# Uttarakhand                     339293                  1.61985e+07
# Kerala                          499808                     52600230
# Haryana                         352254                  4.37462e+07
# Sikkim                            4529                      1520933
# Goa                              15744                      4063307
#
#                               ...              Primary - 2014-2015.1  \
# state                         ...
# Bihar                         ...                                NaN
# Uttar Pradesh                 ...                               8.58
# Manipur                       ...                               9.66
# Assam                         ...                              15.36
# Jharkhand                     ...                               5.48
# Madhya Pradesh                ...                               6.59
# Odisha                        ...                               2.86
# Meghalaya                     ...                               9.46
# Tripura                       ...                               1.28
# Rajasthan                     ...                               5.02
# Chhattisgarh                  ...                               2.91
# Nagaland                      ...                               5.61
# Andhra Pradesh                ...                               6.72
# Arunachal Pradesh             ...                              10.82
# Punjab                        ...                               3.05
# Telangana                     ...                               2.08
# Gujarat                       ...                               0.89
# Karnataka                     ...                               2.02
# Tamil Nadu                    ...                                NaN
# Maharashtra                   ...                               1.26
# Uttarakhand                   ...                               4.04
# Kerala                        ...                                NaN
# Haryana                       ...                               5.61
# Sikkim                        ...                               2.27
# Goa                           ...                               0.73
#
#                   Upper Primary - 2012-2013 Upper Primary - 2013-2014  \
# state
# Bihar                                   NaN                      2.98
# Uttar Pradesh                          1.06                      0.53
# Manipur                                6.06                      7.02
# Assam                                  7.20                      7.05
# Jharkhand                              5.47                      7.42
# Madhya Pradesh                         8.53                     11.70
# Odisha                                 3.81                      2.80
# Meghalaya                              7.85                      6.84
# Tripura                                3.08                      2.72
# Rajasthan                              4.42                      6.03
# Chhattisgarh                           5.42                      3.80
# Nagaland                               9.83                     17.86
# Andhra Pradesh                         3.36                      3.78
# Arunachal Pradesh                      7.47                      5.59
# Punjab                                 2.78                      2.85
# Telangana                               NaN                      4.71
# Gujarat                                5.20                      5.55
# Karnataka                              5.05                      2.51
# Tamil Nadu                             1.24                      4.52
# Maharashtra                            1.74                      0.61
# Uttarakhand                            0.13                      1.68
# Kerala                                  NaN                       NaN
# Haryana                                0.46                      2.55
# Sikkim                                 3.15                      5.14
# Goa                                     NaN                       NaN
#
#                   Upper Primary - 2014-2015 Secondary - 2012-2013  \
# state
# Bihar                                  4.08                 30.14
# Uttar Pradesh                          2.70                   NaN
# Manipur                                4.20                  9.75
# Assam                                 10.51                 26.77
# Jharkhand                              8.99                 18.50
# Madhya Pradesh                         9.20                 13.63
# Odisha                                 3.81                 49.86
# Meghalaya                              6.52                 26.03
# Tripura                                1.99                 25.50
# Rajasthan                              3.07                 13.65
# Chhattisgarh                           5.85                 14.86
# Nagaland                               7.92                 26.51
# Andhra Pradesh                         5.20                 12.72
# Arunachal Pradesh                      6.71                 12.93
# Punjab                                 3.22                  9.80
# Telangana                              2.30                   NaN
# Gujarat                                6.41                 13.55
# Karnataka                              3.85                 39.92
# Tamil Nadu                              NaN                 10.20
# Maharashtra                            1.79                 16.20
# Uttarakhand                            1.19                  9.68
# Kerala                                  NaN                  9.45
# Haryana                                5.81                  8.98
# Sikkim                                 1.57                  9.23
# Goa                                    0.07                  7.96
#
#                   Secondary - 2013-2014 Secondary - 2014-2015  \
# state
# Bihar                             25.33                 25.90
# Uttar Pradesh                      7.30                 10.22
# Manipur                           13.81                 14.38
# Assam                             30.43                 27.06
# Jharkhand                         23.15                 24.00
# Madhya Pradesh                    26.47                 24.77
# Odisha                            49.48                 29.56
# Meghalaya                         24.75                 20.52
# Tripura                           25.09                 28.42
# Rajasthan                         18.77                 13.48
# Chhattisgarh                      23.41                 21.26
# Nagaland                          35.11                 18.23
# Andhra Pradesh                    12.65                 15.71
# Arunachal Pradesh                 14.49                 17.11
# Punjab                             8.83                  8.86
# Telangana                         17.43                 15.53
# Gujarat                           21.61                 25.04
# Karnataka                         27.57                 26.18
# Tamil Nadu                        12.20                  8.10
# Maharashtra                       14.47                 12.87
# Uttarakhand                        8.70                 10.40
# Kerala                            14.46                 12.32
# Haryana                           12.51                 15.89
# Sikkim                            12.89                 15.89
# Goa                                9.58                 11.15
#
#                   Senior Secondary - 2012-2013 Senior Secondary - 2013-2014  \
# state
# Bihar                                      NaN                          NaN
# Uttar Pradesh                              NaN                          NaN
# Manipur                                   7.93                         3.20
# Assam                                     4.69                         7.24
# Jharkhand                                  NaN                          NaN
# Madhya Pradesh                             NaN                         1.55
# Odisha                                     NaN                          NaN
# Meghalaya                                  NaN                          NaN
# Tripura                                   8.87                         9.11
# Rajasthan                                  NaN                          NaN
# Chhattisgarh                               NaN                          NaN
# Nagaland                                 18.29                        14.19
# Andhra Pradesh                            0.35                        11.79
# Arunachal Pradesh                         5.11                        17.07
# Punjab                                    8.28                         5.81
# Telangana                                  NaN                        13.43
# Gujarat                                   0.46                         7.83
# Karnataka                                15.33                          NaN
# Tamil Nadu                                1.87                         4.44
# Maharashtra                               3.20                         3.34
# Uttarakhand                               1.59                          NaN
# Kerala                                     NaN                         6.40
# Haryana                                    NaN                         2.18
# Sikkim                                    8.10                        12.91
# Goa                                      11.26                        13.36
#
#                   Senior Secondary - 2014-2015
# state
# Bihar                                      NaN
# Uttar Pradesh                             2.10
# Manipur                                    NaN
# Assam                                      NaN
# Jharkhand                                 3.41
# Madhya Pradesh                             NaN
# Odisha                                     NaN
# Meghalaya                                  NaN
# Tripura                                   8.93
# Rajasthan                                  NaN
# Chhattisgarh                              2.76
# Nagaland                                  6.97
# Andhra Pradesh                             NaN
# Arunachal Pradesh                        18.42
# Punjab                                    5.83
# Telangana                                 0.77
# Gujarat                                   7.04
# Karnataka                                 1.96
# Tamil Nadu                                3.41
# Maharashtra                               1.83
# Uttarakhand                               3.01
# Kerala                                    0.47
# Haryana                                   5.75
# Sikkim                                   11.76
# Goa                                      13.91
#
# [25 rows x 53 columns]

# %% [markdown]
# ## Drop-out trend: 'Primary - 2014-2015'

# %%
gsva_primary = gsva_drop[['Per Capita GSDP (Rs.)','Primary - 2014-2015']]
gsva_primary.dropna(inplace=True)
gsva_primary['Per Capita GSDP (Rs.)'] = gsva_primary['Per Capita GSDP (Rs.)'].astype(int)
gsva_primary['Primary - 2014-2015'] = gsva_primary['Primary - 2014-2015'].astype(int)
print(gsva_primary)
gsva_primary.plot.scatter(x='Per Capita GSDP (Rs.)',y='Primary - 2014-2015')
# Out:
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                    Per Capita GSDP (Rs.)  Primary - 2014-2015
# state
# Bihar                              33954                    2
# Uttar Pradesh                      49450                    7
# Manipur                            58442                   18
# Assam                              60621                    7
# Jharkhand                          62091                    6
# Madhya Pradesh                     62989                   10
# Odisha                             73979                    2
# Meghalaya                          76228                   10
# Tripura                            77358                    3
# Rajasthan                          84837                    8
# Chhattisgarh                       86860                    1
# Nagaland                           89607                   19
# Andhra Pradesh                    104977                    4
# Arunachal Pradesh                 112718                   10
# Punjab                            126606                    1
# Telangana                         139035                    5
# Gujarat                           141263                    0
# Karnataka                         145141                    2
# Tamil Nadu                        146503                    0
# Maharashtra                       152853                    0
# Uttarakhand                       153076                    3
# Haryana                           164077                    0
# Sikkim                            240274                    4
# Goa                               271793                    0

# %% [markdown]
# ## Drop-out trend: 'Upper Primary - 2014-2015'

# %%
gsva_upper_primary = gsva_drop[['Per Capita GSDP (Rs.)','Upper Primary - 2014-2015']]
gsva_upper_primary.dropna(inplace=True)
gsva_upper_primary['Per Capita GSDP (Rs.)'] = gsva_upper_primary['Per Capita GSDP (Rs.)'].astype(int)
gsva_upper_primary['Upper Primary - 2014-2015'] = gsva_upper_primary['Upper Primary - 2014-2015'].astype(int)
print(gsva_upper_primary)
gsva_upper_primary.plot.scatter(x='Per Capita GSDP (Rs.)',y='Upper Primary - 2014-2015')
# Out:
#                    Per Capita GSDP (Rs.)  Upper Primary - 2014-2015
# state
# Bihar                              33954                          4
# Uttar Pradesh                      49450                          2
# Manipur                            58442                          4
# Assam                              60621                         10
# Jharkhand                          62091                          8
# Madhya Pradesh                     62989                          9
# Odisha                             73979                          3
# Meghalaya                          76228                          6
# Tripura                            77358                          1
# Rajasthan                          84837                          3
# Chhattisgarh                       86860                          5
# Nagaland                           89607                          7
# Andhra Pradesh                    104977                          5
# Arunachal Pradesh                 112718                          6
# Punjab                            126606                          3
# Telangana                         139035                          2
# Gujarat                           141263                          6
# Karnataka                         145141                          3
# Maharashtra                       152853                          1
# Uttarakhand                       153076                          1
# Haryana                           164077                          5
# Sikkim                            240274                          1
# Goa                               271793                          0
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Drop-out trend: 'Secondary - 2014-2015'

# %%
gsva_secondary = gsva_drop[['Per Capita GSDP (Rs.)','Secondary - 2014-2015']]
gsva_secondary.dropna(inplace=True)
gsva_secondary['Per Capita GSDP (Rs.)'] = gsva_secondary['Per Capita GSDP (Rs.)'].astype(int)
gsva_secondary['Secondary - 2014-2015'] = gsva_secondary['Secondary - 2014-2015'].astype(int)
print(gsva_secondary)
gsva_secondary.plot.scatter(x='Per Capita GSDP (Rs.)',y='Secondary - 2014-2015')
# Out:
#                    Per Capita GSDP (Rs.)  Secondary - 2014-2015
# state
# Bihar                              33954                     25
# Uttar Pradesh                      49450                     10
# Manipur                            58442                     14
# Assam                              60621                     27
# Jharkhand                          62091                     24
# Madhya Pradesh                     62989                     24
# Odisha                             73979                     29
# Meghalaya                          76228                     20
# Tripura                            77358                     28
# Rajasthan                          84837                     13
# Chhattisgarh                       86860                     21
# Nagaland                           89607                     18
# Andhra Pradesh                    104977                     15
# Arunachal Pradesh                 112718                     17
# Punjab                            126606                      8
# Telangana                         139035                     15
# Gujarat                           141263                     25
# Karnataka                         145141                     26
# Tamil Nadu                        146503                      8
# Maharashtra                       152853                     12
# Uttarakhand                       153076                     10
# Kerala                            154778                     12
# Haryana                           164077                     15
# Sikkim                            240274                     15
# Goa                               271793                     11
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\govindam.kumar\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# - For all the 3 categories(primary, upper primary and secondary), it can be observed that there is almost linear relationship between drop-out rate and per capita GSDP.
# - As per-capita GSDP increases, drop-out rate decreases.
# - From the analysis in Part I-B, you have observed that low per-capita points to more dependence on agriculture and lack of industries.
# - So, it is possible that, in the states where people are not educated, industries do not get set-up as they require skilled labour.
# - It is also possible that people are educated upto some extend, but because of lack of opportunity, they are not willing to go for higher education.
# - Recommendation is more money should be spend on quality education.
